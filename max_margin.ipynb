# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import cvxpy as cp

import torch
from torch import nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader
import torch.optim as optim
import os
import random

import sys
sys.path.insert(0, './mlopt-micp')
sys.path.insert(0, './mlopt-micp/cartpole')

import optimizer
from problem import Cartpole
from src.ae import Encoder, get_cartpole_encoder

# %%
def euclidean_dist(x,y):
    # x: NxD
    # y: MxD
    n = x.size(0)
    m = y.size(0)
    d = x.size(1)
    assert d == y.size(1)
    
    x = x.unsqueeze(1).expand(n, m, d)
    y = y.unsqueeze(0).expand(n, m, d)
    return torch.pow(x-y, 2).sum(2)

# %%
pp = Cartpole()

# %%
print('Total number of classes: {}'.format(pp.n_strategies))
print('Length of feature vector: {}'.format(pp.n_features))
# Out:
# Total number of classes: 581
# Length of feature vector: 13

# %%
dim_in, dim_z = pp.n_features, 2

enc = get_cartpole_encoder(dim_in, dim_z).cuda()
enc(torch.from_numpy(pp.features[:2]).float().cuda())

# training parameters
TRAINING_ITERATIONS = int(5000)
BATCH_SIZE = int(64)
CHECKPOINT_AFTER = int(1250)
SAVEPOINT_AFTER = int(2500)

rand_idx = list(np.arange(0, pp.n_strategies-1))

indices = [rand_idx[ii * BATCH_SIZE:(ii + 1) * BATCH_SIZE] for ii in range((len(rand_idx) + BATCH_SIZE - 1) // BATCH_SIZE)]
random.shuffle(indices)

enc_dict = {}
str_dict = {}
for ii in range(len(pp.features)):
    str_idx = int(pp.labels[ii,0])
    str_dict[ii] = str_idx
    if str_idx in enc_dict.keys():
        enc_dict[str_idx] += [ii]
    else:
        enc_dict[str_idx] = [ii]
        
feats = torch.from_numpy(pp.features).float().cuda()
strat_slices = tuple(enc_dict.values())

# %%
torch.cuda.empty_cache()
train_inds= int(pp.training_batch_percentage*pp.n_probs)
n = BATCH_SIZE; d = dim_z
m = pp.n_strategies
#for tt in range(training_iters):
#compute centroids
embeds = enc(feats)
centroids = torch.zeros(pp.n_strategies,dim_z).cuda()
for ii in range(pp.n_strategies):
    centroids[ii,:] = torch.mean(embeds[enc_dict[ii],:])
    
#n,d = embeds[batch_inds,:].shape
#m = centroids.size(0)

batch_inds = np.random.randint(0, train_inds,BATCH_SIZE)
diff = embeds[batch_inds,:].unsqueeze(1).expand(n,m,d) - centroids.unsqueeze(0).expand(n,m,d)
l2_dist = torch.norm(diff,dim=-1); l1_dist = torch.norm(diff,p=1,dim=-1)

dists = torch.where(l2_dist <= 1., l2_dist, l1_dist)

# #sample training points
# batch_inds = np.random.randint(0, train_inds,BATCH_SIZE)
# dists = torch.cdist(embeds[batch_inds,:],centroids)
margins = dists[torch.arange(BATCH_SIZE),pp.labels[batch_inds,0].astype(int)][:,None]
loss_mask = torch.zeros(BATCH_SIZE,pp.n_strategies).cuda()
loss_mask[torch.arange(BATCH_SIZE),pp.labels[batch_inds,0].astype(int)] = -1.
losses = margins + torch.sum(torch.max(margins-dists+1,torch.zeros(1).cuda()),dim=1)[:,None]

np.mean(np.equal(torch.argmin(dists,axis=1).cpu().numpy(),pp.labels[batch_inds,0].astype(int)))

#torch.sum(torch.max(loss_mask+margins-dists+1,torch.zeros(1).cuda()),dim=1)[:,None]
# Out:
# tensor([[0.2954],
#         [0.2918],
#         [0.2977],
#         [0.2936],
#         [0.2978],
#         [0.2947],
#         [0.2994],
#         [0.2885],
#         [0.2985],
#         [0.3010],
#         [0.2891],
#         [0.3057],
#         [0.2937],
#         [0.2958],
#         [0.2929],
#         [0.3061],
#         [0.2904],
#         [0.2994],
#         [0.3006],
#         [0.2918],
#         [0.3008],
#         [0.2991],
#         [0.2986],
#         [0.2955],
#         [0.2986],
#         [0.3060],
#         [0.3073],
#         [0.2963],
#         [0.2929],
#         [0.3032],
#         [0.3010],
#         [0.3008],
#         [0.2903],
#         [0.3077],
#         [0.2976],
#         [0.2940],
#         [0.2982],
#         [0.2833],
#         [0.3009],
#         [0.2988],
#         [0.2955],
#         [0.2947],
#         [0.2959],
#         [0.2881],
#         [0.3004],
#         [0.2995],
#         [0.2985],
#         [0.3008],
#         [0.3034],
#         [0.2998],
#         [0.2936],
#         [0.2961],
#         [0.2990],
#         [0.3010],
#         [0.2907],
#         [0.2970],
#         [0.3022],
#         [0.3026],
#         [0.2998],
#         [0.2977],
#         [0.2963],
#         [0.2981],
#         [0.2974],
#         [0.3040]], device='cuda:0', grad_fn=<UnsqueezeBackward0>)

# %%
optimizer = optim.Adam(enc.parameters(),lr=1e-3)
N = pp.n_strategies # number of classes in training set
Nc = 100 # number of classes per episode
Ns = 20  # number of support examples per class
Nq = 20  # number of query examples per class
BATCH_SIZE = int(2056)
training_iters = 10000
n = BATCH_SIZE; d = dim_z
m = pp.n_strategies
centroids = 10*torch.randn(pp.n_strategies,dim_z).cuda()
tau = 1e-1
for tt in range(training_iters):
    optimizer.zero_grad()

    train_inds= int(pp.training_batch_percentage*pp.n_probs)
    
    #compute centroids
    embeds = enc(feats)
    c_curr = torch.zeros(pp.n_strategies,dim_z).cuda()
    for ii in range(pp.n_strategies):
        c_curr[ii,:] = torch.mean(embeds[enc_dict[ii],:])
        
    centroids = (1-tau)*centroids + tau*c_curr.detach()

    #sample training points
    batch_inds = np.random.randint(0, train_inds,BATCH_SIZE)
    diff = embeds[batch_inds,:].unsqueeze(1).expand(n,m,d) - centroids.unsqueeze(0).expand(n,m,d)
    l2_dist = torch.norm(diff,dim=-1); l1_dist = torch.norm(diff,p=1,dim=-1)

    dists = torch.where(l2_dist <= 1., l2_dist, l1_dist)
    #dists = torch.cdist(embeds[batch_inds,:],centroids)
    margins = dists[torch.arange(BATCH_SIZE),pp.labels[batch_inds,0].astype(int)][:,None]
    loss_mask = torch.zeros(BATCH_SIZE,pp.n_strategies).cuda()
    loss_mask[torch.arange(BATCH_SIZE),pp.labels[batch_inds,0].astype(int)] = -1.
    losses = 0.5*margins + 0.5*torch.sum(torch.max(loss_mask+margins-dists+5,torch.zeros(1).cuda()),dim=1)[:,None]

    if tt % 50 == 0: #print for debug
        acc = np.mean(np.equal(torch.argmin(dists,axis=1).cpu().numpy(),pp.labels[batch_inds,0].astype(int)))
        print(acc,torch.mean(losses))
    
    torch.mean(losses).backward()
    #torch.nn.utils.clip_grad_norm_(enc.parameters(),1.)
    optimizer.step()
# Out:
# 0.0014591439688715954 tensor(1431.2437, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.013618677042801557 tensor(1192.1442, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.007782101167315175 tensor(1124.6624, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0038910505836575876 tensor(1447.4426, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.00048638132295719845 tensor(1488.0829, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0 tensor(1384.6669, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.004377431906614786 tensor(1137.2689, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0009727626459143969 tensor(1026.2563, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0024319066147859923 tensor(1125.9775, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0009727626459143969 tensor(988.5848, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0 tensor(857.2982, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0 tensor(813.2253, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0014591439688715954 tensor(804.8226, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0 tensor(782.4325, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.00048638132295719845 tensor(760.9206, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.00048638132295719845 tensor(686.2076, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0014591439688715954 tensor(664.1925, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.00048638132295719845 tensor(580.4086, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0024319066147859923 tensor(497.7789, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0014591439688715954 tensor(434.0914, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0 tensor(395.0424, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.004377431906614786 tensor(353.4011, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0029182879377431907 tensor(296.6155, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0024319066147859923 tensor(280.1700, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0048638132295719845 tensor(275.5779, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0048638132295719845 tensor(264.0848, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.005350194552529183 tensor(246.8168, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.00924124513618677 tensor(248.4053, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.00924124513618677 tensor(212.5625, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.005836575875486381 tensor(223.7212, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.006809338521400778 tensor(208.3207, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.014591439688715954 tensor(203.6797, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.01848249027237354 tensor(207.0737, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.02529182879377432 tensor(194.9811, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.019455252918287938 tensor(180.4641, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.023346303501945526 tensor(183.0825, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.027237354085603113 tensor(177.7408, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.023832684824902722 tensor(184.3480, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.030155642023346304 tensor(157.9159, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.03453307392996109 tensor(157.1055, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.03453307392996109 tensor(166.4884, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.027237354085603113 tensor(191.2789, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.028696498054474707 tensor(143.2008, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.03745136186770428 tensor(140.2428, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.035505836575875485 tensor(140.4664, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0325875486381323 tensor(145.7117, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.03988326848249027 tensor(138.7091, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.03356031128404669 tensor(131.6572, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.03939688715953307 tensor(123.6559, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.035505836575875485 tensor(144.4995, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.030155642023346304 tensor(143.2607, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.037937743190661476 tensor(130.3768, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.04426070038910506 tensor(115.9058, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.04182879377431906 tensor(124.7285, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.04231517509727627 tensor(113.9896, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.047665369649805445 tensor(120.1047, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.04377431906614786 tensor(123.8058, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.038910505836575876 tensor(116.2038, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.046206225680933855 tensor(105.3250, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.04571984435797665 tensor(102.2745, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.04571984435797665 tensor(111.6871, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.04134241245136187 tensor(101.2712, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0967898832684825 tensor(94.9188, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.08852140077821012 tensor(104.2599, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.07198443579766536 tensor(102.4916, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.08803501945525292 tensor(102.8222, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0914396887159533 tensor(95.6488, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.07052529182879377 tensor(84.1935, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.053501945525291826 tensor(96.4981, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.06031128404669261 tensor(91.1957, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.06760700389105058 tensor(83.0913, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0632295719844358 tensor(88.9584, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.07198443579766536 tensor(95.9364, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.07392996108949416 tensor(90.0289, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0943579766536965 tensor(82.6015, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.055933852140077824 tensor(89.1014, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.07684824902723736 tensor(91.6187, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.09192607003891051 tensor(85.6106, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.061284046692607 tensor(86.9008, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.04912451361867704 tensor(89.8307, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.17023346303501946 tensor(78.5880, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.17558365758754862 tensor(78.1612, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.1916342412451362 tensor(85.9638, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.16536964980544747 tensor(80.8746, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.16731517509727625 tensor(83.7167, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.14688715953307394 tensor(85.6020, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.14737354085603113 tensor(77.9461, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.12791828793774318 tensor(81.9409, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.11138132295719845 tensor(87.6173, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.07636186770428016 tensor(87.4248, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.12305447470817121 tensor(85.5175, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.13521400778210116 tensor(85.2106, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.10894941634241245 tensor(79.0531, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0967898832684825 tensor(82.5300, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.12743190661478598 tensor(86.9979, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.13472762645914396 tensor(78.3415, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.13715953307392997 tensor(83.7369, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.09970817120622569 tensor(82.0376, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0914396887159533 tensor(81.6327, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.10019455252918288 tensor(81.4420, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.11575875486381323 tensor(82.5916, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.1614785992217899 tensor(83.1640, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.10116731517509728 tensor(87.3952, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.11235408560311284 tensor(87.3278, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.27529182879377434 tensor(77.5564, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.2913424124513619 tensor(88.9806, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.28550583657587547 tensor(83.2617, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.2796692607003891 tensor(80.6112, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.2504863813229572 tensor(81.6263, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.06760700389105058 tensor(82.7230, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.26702334630350194 tensor(86.7716, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.35894941634241245 tensor(86.3148, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.33073929961089493 tensor(84.3171, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.26313229571984437 tensor(81.8471, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.30836575875486383 tensor(83.6183, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3117704280155642 tensor(83.4829, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.1502918287937743 tensor(83.6108, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3093385214007782 tensor(81.4152, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.1264591439688716 tensor(83.8546, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.16536964980544747 tensor(81.8963, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.13570038910505836 tensor(79.5624, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.07733463035019456 tensor(79.1902, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.06663424124513619 tensor(85.6896, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.08268482490272373 tensor(79.1501, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.13813229571984437 tensor(77.8292, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.24756809338521402 tensor(77.8863, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.193579766536965 tensor(78.1775, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.0622568093385214 tensor(77.0194, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.25632295719844356 tensor(87.8890, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.07198443579766536 tensor(77.8293, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.36964980544747084 tensor(80.6164, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.24659533073929962 tensor(84.4665, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3550583657587549 tensor(75.0510, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3730544747081712 tensor(81.3551, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.38764591439688717 tensor(80.8926, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3020428015564202 tensor(80.0983, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.38910505836575876 tensor(80.5103, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.22616731517509728 tensor(76.1660, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3715953307392996 tensor(79.0443, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.37013618677042803 tensor(80.7424, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.375 tensor(81.5968, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3526264591439689 tensor(74.5840, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.36284046692607 tensor(82.6794, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.39007782101167315 tensor(77.9627, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3463035019455253 tensor(79.4192, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.40077821011673154 tensor(81.8405, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.37013618677042803 tensor(78.3143, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3730544747081712 tensor(76.8410, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3769455252918288 tensor(81.3549, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.35797665369649806 tensor(77.2158, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3954280155642023 tensor(71.4986, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3764591439688716 tensor(75.1101, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.36040856031128404 tensor(78.4472, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.33025291828793774 tensor(73.9531, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.313715953307393 tensor(74.2050, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3438715953307393 tensor(82.1517, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3545719844357977 tensor(75.3140, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3428988326848249 tensor(83.0775, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.35797665369649806 tensor(76.9592, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.20428015564202334 tensor(76.6992, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.1892023346303502 tensor(77.8354, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3866731517509728 tensor(76.6066, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.384727626459144 tensor(75.2479, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3642996108949416 tensor(73.7271, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.11575875486381323 tensor(79.7043, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3715953307392996 tensor(78.2824, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.35749027237354086 tensor(75.0035, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3317120622568093 tensor(81.2147, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3720817120622568 tensor(75.2838, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.38959143968871596 tensor(76.3225, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3535992217898833 tensor(78.8406, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3857003891050584 tensor(77.8674, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.39299610894941633 tensor(75.0145, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3404669260700389 tensor(76.0935, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.21108949416342412 tensor(78.6849, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.22714007782101167 tensor(72.2873, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.24756809338521402 tensor(72.6216, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.17023346303501946 tensor(71.6257, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.07344357976653697 tensor(76.1386, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.30544747081712065 tensor(74.2758, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.36040856031128404 tensor(76.3736, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.316147859922179 tensor(78.3705, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3321984435797665 tensor(76.9615, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.2227626459143969 tensor(73.6255, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.18093385214007782 tensor(76.1412, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.20817120622568094 tensor(74.0048, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3326848249027237 tensor(72.6689, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.33852140077821014 tensor(75.3100, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.33949416342412453 tensor(74.1763, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.09824902723735408 tensor(73.7734, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.19066147859922178 tensor(77.1129, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.17607003891050585 tensor(74.0300, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.2811284046692607 tensor(75.2243, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.18968871595330739 tensor(77.0688, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.26507782101167315 tensor(74.9667, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.29815175097276264 tensor(74.0669, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3219844357976654 tensor(78.5828, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.31857976653696496 tensor(75.8680, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.3317120622568093 tensor(72.9133, device='cuda:0', grad_fn=<MeanBackward0>)
# 0.06760700389105058 tensor(76.8158, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
#test script
n_train_strategies = pp.n_strategies #store how many strats in train set
c_k = torch.zeros((n_train_strategies,dim_z)) 
embeddings = enc(feats) #embed training points
for ii in range(n_train_strategies): #compute train centroids
    inds = enc_dict[ii]
    c_k[ii,:] = torch.mean(embeddings[inds,:],axis=0).cuda()

#compute strategy dictionary for all problems
pp.training_batch_percentage = 1.
pp.construct_strategies()
strat_lookup = {}
for k, v in pp.strategy_dict.items():
    strat_lookup[v[0]] = v[1:]

#setup for test
test_feats = torch.from_numpy(pp.features[int(0.9*pp.n_probs):,:]).float().cuda()
test_enc = enc(test_feats).cuda()
test_dists = torch.cdist(test_enc,c_k.cuda()).detach().cpu().numpy()
test_start = int(0.9*pp.n_probs)
n_test = int(0.1*pp.n_probs)
ind_max = np.argsort(test_dists)[:,:pp.n_evals]
feasible = np.zeros(n_test)
costs = np.zeros(n_test)

# %%
prob_success = False

for ii in range(n_test):
    for jj in range(pp.n_evals):
        y_guess = strat_lookup[ind_max[ii,jj]]
        try:
            prob_success, cost, solve_time = pp.solve_mlopt_prob_with_idx(ii+test_start, y_guess)
            if prob_success:
                feasible[ii] = 1.
                costs[ii] = cost
                print('Succeded at {} with {} tries'.format(ii,jj+1))
                break
        except:
            print('mosek failed at '.format(ii))
# Out:
# Succeded at 2 with 2 tries
# Succeded at 3 with 4 tries
# Succeded at 5 with 5 tries
# Succeded at 6 with 1 tries
# Succeded at 8 with 1 tries
# Succeded at 11 with 1 tries
# Succeded at 13 with 3 tries
# Succeded at 14 with 1 tries
# Succeded at 17 with 6 tries
# Succeded at 18 with 1 tries
# Succeded at 19 with 1 tries
# Succeded at 20 with 3 tries
# Succeded at 23 with 3 tries
# Succeded at 24 with 4 tries
# Succeded at 26 with 2 tries
# Succeded at 27 with 9 tries
# Succeded at 28 with 5 tries
# Succeded at 29 with 8 tries
# Succeded at 32 with 2 tries
# Succeded at 34 with 2 tries
# Succeded at 35 with 9 tries
# Succeded at 37 with 1 tries
# Succeded at 39 with 3 tries
# Succeded at 40 with 1 tries
# Succeded at 41 with 3 tries
# Succeded at 42 with 3 tries
# Succeded at 43 with 1 tries
# Succeded at 44 with 2 tries
# Succeded at 45 with 2 tries
# Succeded at 46 with 7 tries
# Succeded at 47 with 5 tries
# Succeded at 48 with 6 tries
# Succeded at 49 with 5 tries
# Succeded at 51 with 3 tries
# Succeded at 52 with 3 tries
# Succeded at 56 with 3 tries
# Succeded at 59 with 4 tries
# Succeded at 60 with 1 tries
# Succeded at 61 with 3 tries
# Succeded at 62 with 4 tries
# Succeded at 64 with 2 tries
# Succeded at 65 with 2 tries
# Succeded at 66 with 3 tries
# Succeded at 68 with 3 tries
# Succeded at 70 with 1 tries
# Succeded at 71 with 1 tries
# Succeded at 72 with 4 tries
# Succeded at 74 with 3 tries
# Succeded at 75 with 5 tries
# Succeded at 76 with 1 tries
# Succeded at 77 with 6 tries
# Succeded at 78 with 3 tries
# Succeded at 79 with 3 tries
# Succeded at 81 with 2 tries
# Succeded at 82 with 8 tries
# Succeded at 83 with 4 tries
# Succeded at 85 with 3 tries
# Succeded at 86 with 3 tries
# Succeded at 87 with 3 tries
# Succeded at 88 with 3 tries
# Succeded at 90 with 1 tries
# Succeded at 92 with 3 tries
# Succeded at 93 with 3 tries
# Succeded at 95 with 1 tries
# Succeded at 97 with 1 tries
# Succeded at 98 with 5 tries
# Succeded at 99 with 3 tries
# Succeded at 101 with 1 tries
# Succeded at 102 with 5 tries
# Succeded at 103 with 8 tries
# Succeded at 105 with 3 tries
# Succeded at 106 with 3 tries
# Succeded at 107 with 1 tries
# Succeded at 108 with 3 tries
# Succeded at 109 with 8 tries
# Succeded at 111 with 1 tries
# Succeded at 112 with 4 tries
# Succeded at 113 with 7 tries
# Succeded at 114 with 3 tries
# Succeded at 115 with 8 tries
# Succeded at 116 with 3 tries
# Succeded at 118 with 9 tries
# Succeded at 119 with 3 tries
# Succeded at 121 with 3 tries
# Succeded at 122 with 3 tries
# Succeded at 124 with 2 tries
# Succeded at 126 with 3 tries
# Succeded at 127 with 1 tries
# Succeded at 129 with 4 tries
# Succeded at 130 with 1 tries
# Succeded at 131 with 1 tries
# Succeded at 133 with 3 tries
# Succeded at 134 with 2 tries
# Succeded at 136 with 3 tries
# Succeded at 137 with 6 tries
# Succeded at 138 with 5 tries
# Succeded at 139 with 7 tries
# Succeded at 140 with 10 tries
# Succeded at 141 with 3 tries
# Succeded at 142 with 3 tries
# Succeded at 143 with 6 tries
# Succeded at 145 with 5 tries
# Succeded at 147 with 5 tries
# Succeded at 148 with 7 tries
# Succeded at 149 with 7 tries
# Succeded at 150 with 8 tries
# Succeded at 152 with 1 tries
# Succeded at 153 with 2 tries
# Succeded at 154 with 3 tries
# Succeded at 155 with 10 tries
# Succeded at 156 with 1 tries
# Succeded at 158 with 3 tries
# Succeded at 159 with 1 tries
# Succeded at 160 with 2 tries
# Succeded at 161 with 1 tries
# Succeded at 162 with 1 tries
# Succeded at 163 with 5 tries
# Succeded at 166 with 9 tries
# Succeded at 167 with 8 tries
# Succeded at 168 with 3 tries
# Succeded at 169 with 3 tries
# Succeded at 170 with 3 tries
# Succeded at 171 with 3 tries
# Succeded at 174 with 4 tries
# Succeded at 175 with 8 tries
# Succeded at 177 with 3 tries
# Succeded at 178 with 10 tries
# Succeded at 179 with 6 tries
# Succeded at 180 with 4 tries
# Succeded at 181 with 7 tries
# Succeded at 183 with 5 tries
# Succeded at 187 with 2 tries
# Succeded at 188 with 7 tries
# Succeded at 189 with 1 tries
# Succeded at 190 with 7 tries
# Succeded at 193 with 3 tries
# Succeded at 194 with 1 tries
# Succeded at 195 with 1 tries
# Succeded at 196 with 4 tries
# Succeded at 197 with 3 tries
# Succeded at 199 with 3 tries
# Succeded at 201 with 1 tries
# Succeded at 202 with 3 tries
# Succeded at 203 with 5 tries
# Succeded at 204 with 5 tries
# Succeded at 205 with 2 tries
# Succeded at 207 with 4 tries
# Succeded at 209 with 1 tries
# Succeded at 210 with 3 tries
# Succeded at 213 with 7 tries
# Succeded at 215 with 5 tries
# Succeded at 216 with 3 tries
# Succeded at 217 with 5 tries
# Succeded at 218 with 5 tries
# Succeded at 219 with 3 tries
# Succeded at 220 with 3 tries
# Succeded at 221 with 2 tries
# Succeded at 222 with 6 tries
# Succeded at 223 with 3 tries
# Succeded at 225 with 1 tries
# Succeded at 226 with 1 tries
# Succeded at 227 with 2 tries
# Succeded at 228 with 1 tries
# Succeded at 230 with 7 tries
# Succeded at 231 with 3 tries
# Succeded at 232 with 1 tries
# Succeded at 233 with 3 tries
# Succeded at 234 with 4 tries
# Succeded at 235 with 2 tries
# Succeded at 237 with 4 tries
# Succeded at 238 with 1 tries
# Succeded at 239 with 8 tries
# Succeded at 240 with 6 tries
# Succeded at 241 with 8 tries
# Succeded at 242 with 7 tries
# Succeded at 244 with 4 tries
# Succeded at 245 with 4 tries
# Succeded at 246 with 3 tries
# Succeded at 247 with 1 tries
# Succeded at 249 with 3 tries
# Succeded at 250 with 2 tries
# Succeded at 251 with 2 tries
# Succeded at 253 with 5 tries
# Succeded at 254 with 4 tries
# Succeded at 255 with 3 tries
# Succeded at 256 with 1 tries
# Succeded at 259 with 5 tries
# Succeded at 262 with 2 tries
# Succeded at 263 with 3 tries
# Succeded at 264 with 4 tries
# Succeded at 265 with 1 tries
# Succeded at 266 with 3 tries
# Succeded at 267 with 1 tries
# Succeded at 268 with 8 tries
# Succeded at 269 with 1 tries
# Succeded at 271 with 1 tries
# Succeded at 272 with 1 tries
# Succeded at 273 with 10 tries
# Succeded at 275 with 3 tries
# Succeded at 276 with 4 tries
# Succeded at 277 with 4 tries
# Succeded at 279 with 9 tries
# Succeded at 280 with 1 tries
# Succeded at 281 with 5 tries
# Succeded at 283 with 1 tries
# Succeded at 290 with 10 tries
# Succeded at 292 with 3 tries
# Succeded at 293 with 3 tries
# Succeded at 295 with 3 tries
# Succeded at 298 with 3 tries
# Succeded at 299 with 3 tries
# Succeded at 300 with 2 tries
# Succeded at 301 with 2 tries
# Succeded at 302 with 5 tries
# Succeded at 304 with 4 tries
# Succeded at 307 with 2 tries
# Succeded at 308 with 1 tries
# Succeded at 309 with 4 tries
# Succeded at 310 with 1 tries
# Succeded at 311 with 3 tries
# Succeded at 312 with 7 tries
# Succeded at 313 with 5 tries
# Succeded at 314 with 3 tries
# Succeded at 315 with 5 tries
# Succeded at 316 with 7 tries
# Succeded at 318 with 2 tries
# Succeded at 320 with 3 tries
# Succeded at 322 with 1 tries
# Succeded at 323 with 1 tries
# Succeded at 324 with 1 tries
# Succeded at 325 with 3 tries
# Succeded at 326 with 9 tries
# Succeded at 327 with 3 tries
# Succeded at 328 with 1 tries
# Succeded at 329 with 7 tries
# Succeded at 330 with 3 tries
# Succeded at 331 with 3 tries
# Succeded at 332 with 2 tries
# Succeded at 333 with 3 tries
# Succeded at 334 with 6 tries
# Succeded at 335 with 4 tries
# Succeded at 338 with 7 tries
# Succeded at 339 with 9 tries
# Succeded at 340 with 3 tries
# Succeded at 342 with 2 tries
# Succeded at 343 with 1 tries
# Succeded at 344 with 8 tries
# Succeded at 345 with 8 tries
# Succeded at 346 with 3 tries
# Succeded at 347 with 2 tries
# Succeded at 348 with 1 tries
# Succeded at 349 with 3 tries
# Succeded at 350 with 9 tries
# Succeded at 353 with 3 tries
# Succeded at 354 with 2 tries
# Succeded at 355 with 3 tries
# Succeded at 356 with 2 tries
# Succeded at 357 with 1 tries
# Succeded at 358 with 8 tries
# Succeded at 359 with 6 tries
# Succeded at 360 with 1 tries
# Succeded at 361 with 3 tries
# Succeded at 362 with 4 tries
# Succeded at 363 with 3 tries
# Succeded at 364 with 3 tries
# Succeded at 365 with 3 tries
# Succeded at 366 with 9 tries
# Succeded at 367 with 9 tries
# Succeded at 368 with 1 tries
# Succeded at 370 with 3 tries
# Succeded at 371 with 4 tries
# Succeded at 373 with 6 tries
# Succeded at 374 with 3 tries
# Succeded at 375 with 5 tries
# Succeded at 376 with 1 tries
# Succeded at 377 with 3 tries
# Succeded at 378 with 6 tries
# Succeded at 379 with 3 tries
# Succeded at 382 with 8 tries
# Succeded at 385 with 8 tries
# Succeded at 386 with 3 tries
# Succeded at 387 with 4 tries
# Succeded at 388 with 1 tries
# Succeded at 389 with 6 tries
# Succeded at 390 with 7 tries
# Succeded at 391 with 4 tries
# Succeded at 392 with 6 tries
# Succeded at 393 with 2 tries
# Succeded at 394 with 9 tries
# Succeded at 396 with 2 tries
# Succeded at 397 with 8 tries
# Succeded at 401 with 9 tries
# Succeded at 402 with 1 tries
# Succeded at 403 with 1 tries
# Succeded at 404 with 1 tries
# Succeded at 407 with 1 tries
# Succeded at 408 with 4 tries
# Succeded at 409 with 1 tries
# Succeded at 410 with 8 tries
# Succeded at 411 with 3 tries
# Succeded at 412 with 1 tries
# Succeded at 414 with 1 tries
# Succeded at 415 with 5 tries
# Succeded at 417 with 5 tries
# Succeded at 418 with 3 tries
# Succeded at 419 with 1 tries
# Succeded at 420 with 2 tries
# Succeded at 421 with 2 tries
# Succeded at 424 with 6 tries
# Succeded at 425 with 3 tries
# Succeded at 427 with 1 tries
# Succeded at 428 with 3 tries
# Succeded at 430 with 5 tries
# Succeded at 431 with 1 tries
# Succeded at 432 with 1 tries
# Succeded at 434 with 4 tries
# Succeded at 435 with 3 tries
# Succeded at 436 with 8 tries
# Succeded at 437 with 3 tries
# Succeded at 439 with 9 tries
# Succeded at 440 with 7 tries
# Succeded at 441 with 7 tries
# Succeded at 442 with 4 tries
# Succeded at 443 with 3 tries
# Succeded at 444 with 2 tries
# Succeded at 445 with 1 tries
# Succeded at 446 with 5 tries
# Succeded at 447 with 10 tries
# Succeded at 449 with 1 tries
# Succeded at 451 with 4 tries
# Succeded at 453 with 3 tries
# Succeded at 454 with 3 tries
# Succeded at 455 with 1 tries
# Succeded at 456 with 3 tries
# Succeded at 459 with 6 tries
# Succeded at 461 with 3 tries
# Succeded at 463 with 3 tries
# Succeded at 464 with 3 tries
# Succeded at 466 with 3 tries
# Succeded at 467 with 1 tries
# Succeded at 469 with 4 tries
# Succeded at 470 with 1 tries
# Succeded at 472 with 1 tries
# Succeded at 473 with 1 tries
# Succeded at 474 with 3 tries
# Succeded at 475 with 5 tries
# Succeded at 477 with 1 tries
# Succeded at 480 with 3 tries
# Succeded at 481 with 3 tries
# Succeded at 482 with 8 tries
# Succeded at 484 with 7 tries
# Succeded at 485 with 2 tries
# Succeded at 487 with 3 tries
# Succeded at 488 with 3 tries
# Succeded at 489 with 10 tries
# Succeded at 490 with 1 tries
# Succeded at 492 with 3 tries
# Succeded at 495 with 1 tries
# Succeded at 496 with 3 tries
# Succeded at 497 with 1 tries
# Succeded at 499 with 1 tries
# Succeded at 500 with 1 tries
# Succeded at 501 with 5 tries
# Succeded at 502 with 1 tries
# Succeded at 505 with 3 tries
# Succeded at 506 with 8 tries
# Succeded at 508 with 1 tries
# Succeded at 510 with 3 tries
# Succeded at 511 with 8 tries
# Succeded at 513 with 3 tries
# Succeded at 514 with 8 tries
# Succeded at 515 with 3 tries
# Succeded at 518 with 5 tries
# Succeded at 519 with 4 tries
# Succeded at 520 with 1 tries
# Succeded at 523 with 1 tries
# Succeded at 525 with 7 tries
# Succeded at 526 with 10 tries
# Succeded at 528 with 1 tries
# Succeded at 529 with 1 tries
# Succeded at 530 with 1 tries
# Succeded at 531 with 3 tries
# Succeded at 532 with 8 tries
# Succeded at 533 with 5 tries
# Succeded at 534 with 3 tries
# Succeded at 535 with 1 tries
# Succeded at 536 with 2 tries
# Succeded at 538 with 1 tries
# Succeded at 539 with 3 tries
# Succeded at 540 with 3 tries
# Succeded at 541 with 3 tries
# Succeded at 542 with 3 tries
# Succeded at 543 with 6 tries
# Succeded at 546 with 1 tries
# Succeded at 547 with 3 tries
# Succeded at 550 with 8 tries
# Succeded at 551 with 8 tries
# Succeded at 552 with 9 tries
# Succeded at 553 with 1 tries
# Succeded at 555 with 1 tries
# Succeded at 556 with 9 tries
# Succeded at 557 with 4 tries
# Succeded at 558 with 3 tries
# Succeded at 559 with 1 tries
# Succeded at 560 with 5 tries
# Succeded at 561 with 1 tries
# Succeded at 562 with 1 tries
# Succeded at 563 with 3 tries
# Succeded at 565 with 3 tries
# Succeded at 566 with 1 tries
# Succeded at 567 with 3 tries
# Succeded at 568 with 3 tries
# Succeded at 569 with 2 tries
# Succeded at 571 with 3 tries
# Succeded at 573 with 2 tries
# Succeded at 574 with 7 tries
# Succeded at 575 with 6 tries
# Succeded at 576 with 3 tries
# Succeded at 578 with 10 tries
# Succeded at 579 with 2 tries
# Succeded at 580 with 3 tries
# Succeded at 582 with 3 tries
# Succeded at 583 with 3 tries
# Succeded at 584 with 1 tries
# Succeded at 585 with 3 tries
# Succeded at 587 with 2 tries
# Succeded at 588 with 1 tries
# Succeded at 589 with 1 tries
# Succeded at 591 with 6 tries
# Succeded at 592 with 4 tries
# Succeded at 593 with 2 tries
# Succeded at 594 with 3 tries
# Succeded at 595 with 1 tries
# Succeded at 596 with 3 tries
# Succeded at 597 with 3 tries
# Succeded at 598 with 8 tries
# Succeded at 599 with 2 tries
# Succeded at 600 with 1 tries
# Succeded at 601 with 2 tries
# Succeded at 602 with 2 tries
# Succeded at 603 with 3 tries
# Succeded at 604 with 3 tries
# Succeded at 605 with 3 tries
# Succeded at 607 with 3 tries
# Succeded at 608 with 5 tries
# Succeded at 609 with 4 tries
# Succeded at 610 with 3 tries
# Succeded at 611 with 1 tries
# Succeded at 613 with 7 tries
# Succeded at 614 with 3 tries
# Succeded at 615 with 3 tries
# Succeded at 616 with 1 tries
# Succeded at 617 with 3 tries
# Succeded at 618 with 2 tries
# Succeded at 619 with 3 tries
# Succeded at 620 with 1 tries
# Succeded at 621 with 1 tries
# Succeded at 622 with 3 tries
# Succeded at 623 with 1 tries
# Succeded at 624 with 1 tries
# Succeded at 625 with 3 tries
# Succeded at 626 with 7 tries
# Succeded at 627 with 3 tries
# Succeded at 628 with 1 tries
# Succeded at 629 with 2 tries
# Succeded at 630 with 1 tries
# Succeded at 632 with 3 tries
# Succeded at 633 with 3 tries
# Succeded at 634 with 9 tries
# Succeded at 635 with 7 tries
# Succeded at 636 with 6 tries
# Succeded at 638 with 6 tries
# Succeded at 639 with 3 tries
# Succeded at 640 with 1 tries
# Succeded at 641 with 3 tries
# Succeded at 642 with 5 tries
# Succeded at 643 with 10 tries
# Succeded at 645 with 3 tries
# Succeded at 646 with 3 tries
# Succeded at 647 with 1 tries
# Succeded at 648 with 1 tries
# Succeded at 649 with 5 tries
# Succeded at 650 with 1 tries
# Succeded at 651 with 1 tries
# Succeded at 652 with 7 tries
# Succeded at 653 with 3 tries
# Succeded at 655 with 2 tries
# Succeded at 656 with 4 tries
# Succeded at 657 with 2 tries
# Succeded at 658 with 1 tries
# Succeded at 659 with 1 tries
# Succeded at 660 with 3 tries
# Succeded at 661 with 3 tries
# Succeded at 662 with 8 tries
# Succeded at 663 with 3 tries
# Succeded at 664 with 1 tries
# Succeded at 665 with 5 tries
# Succeded at 666 with 3 tries
# Succeded at 668 with 1 tries
# Succeded at 670 with 1 tries
# Succeded at 671 with 3 tries
# Succeded at 672 with 2 tries
# Succeded at 674 with 3 tries
# Succeded at 675 with 4 tries
# Succeded at 678 with 3 tries
# Succeded at 679 with 2 tries
# Succeded at 682 with 3 tries
# Succeded at 684 with 9 tries
# Succeded at 687 with 3 tries
# Succeded at 688 with 5 tries
# Succeded at 689 with 2 tries
# Succeded at 690 with 4 tries
# Succeded at 691 with 7 tries
# Succeded at 692 with 3 tries
# Succeded at 693 with 1 tries
# Succeded at 694 with 3 tries
# Succeded at 695 with 4 tries
# Succeded at 696 with 1 tries
# Succeded at 697 with 3 tries
# Succeded at 698 with 1 tries
# Succeded at 699 with 2 tries
# Succeded at 700 with 1 tries
# Succeded at 702 with 5 tries
# Succeded at 703 with 1 tries
# Succeded at 705 with 3 tries
# Succeded at 707 with 2 tries
# Succeded at 708 with 1 tries
# Succeded at 710 with 4 tries
# Succeded at 712 with 5 tries
# Succeded at 713 with 1 tries
# Succeded at 716 with 3 tries
# Succeded at 717 with 3 tries
# Succeded at 718 with 1 tries
# Succeded at 719 with 3 tries
# Succeded at 721 with 3 tries
# Succeded at 722 with 2 tries
# Succeded at 723 with 2 tries
# Succeded at 725 with 4 tries
# Succeded at 726 with 5 tries
# Succeded at 728 with 1 tries
# Succeded at 731 with 7 tries
# Succeded at 732 with 1 tries
# Succeded at 733 with 9 tries
# Succeded at 734 with 1 tries
# Succeded at 736 with 3 tries
# Succeded at 737 with 5 tries
# Succeded at 738 with 1 tries
# Succeded at 739 with 6 tries
# Succeded at 740 with 1 tries
# Succeded at 741 with 4 tries
# Succeded at 742 with 2 tries
# Succeded at 744 with 4 tries
# Succeded at 745 with 1 tries
# Succeded at 746 with 3 tries
# Succeded at 747 with 3 tries
# Succeded at 749 with 7 tries
# Succeded at 750 with 1 tries
# Succeded at 751 with 5 tries
# Succeded at 752 with 1 tries
# Succeded at 753 with 3 tries
# Succeded at 754 with 5 tries
# Succeded at 755 with 7 tries
# Succeded at 757 with 1 tries
# Succeded at 758 with 3 tries
# Succeded at 760 with 3 tries
# Succeded at 761 with 1 tries
# Succeded at 762 with 1 tries
# Succeded at 763 with 4 tries
# Succeded at 765 with 3 tries
# Succeded at 767 with 3 tries
# Succeded at 768 with 6 tries
# Succeded at 770 with 3 tries
# Succeded at 771 with 6 tries
# Succeded at 772 with 3 tries
# Succeded at 774 with 4 tries
# Succeded at 776 with 4 tries
# Succeded at 777 with 1 tries
# Succeded at 778 with 1 tries
# Succeded at 779 with 3 tries
# Succeded at 780 with 3 tries
# Succeded at 781 with 3 tries
# Succeded at 783 with 3 tries
# Succeded at 784 with 2 tries
# Succeded at 785 with 3 tries
# Succeded at 786 with 3 tries
# Succeded at 791 with 3 tries
# Succeded at 792 with 1 tries
# Succeded at 793 with 1 tries
# Succeded at 794 with 3 tries
# Succeded at 795 with 6 tries
# Succeded at 798 with 6 tries
# Succeded at 799 with 1 tries
# Succeded at 800 with 4 tries
# Succeded at 802 with 3 tries
# Succeded at 803 with 7 tries
# Succeded at 804 with 9 tries
# Succeded at 805 with 3 tries
# Succeded at 806 with 5 tries
# Succeded at 807 with 1 tries
# Succeded at 810 with 4 tries
# Succeded at 811 with 6 tries
# Succeded at 812 with 1 tries
# Succeded at 813 with 2 tries
# Succeded at 814 with 4 tries
# Succeded at 815 with 1 tries
# Succeded at 816 with 1 tries
# Succeded at 817 with 1 tries
# Succeded at 819 with 2 tries
# Succeded at 820 with 1 tries
# Succeded at 821 with 4 tries
# Succeded at 822 with 6 tries
# Succeded at 823 with 3 tries
# Succeded at 824 with 3 tries
# Succeded at 825 with 3 tries
# Succeded at 826 with 4 tries
# Succeded at 827 with 6 tries
# Succeded at 828 with 7 tries
# Succeded at 831 with 3 tries
# Succeded at 832 with 8 tries
# Succeded at 833 with 3 tries
# Succeded at 835 with 7 tries
# Succeded at 836 with 3 tries
# Succeded at 838 with 3 tries
# Succeded at 839 with 5 tries
# Succeded at 841 with 1 tries
# Succeded at 842 with 1 tries
# Succeded at 843 with 4 tries
# Succeded at 844 with 8 tries
# Succeded at 845 with 4 tries
# Succeded at 847 with 3 tries
# Succeded at 849 with 1 tries
# Succeded at 850 with 2 tries
# Succeded at 851 with 7 tries
# Succeded at 853 with 4 tries
# Succeded at 854 with 5 tries
# Succeded at 855 with 1 tries
# Succeded at 856 with 3 tries
# Succeded at 857 with 1 tries
# Succeded at 858 with 7 tries
# Succeded at 859 with 1 tries
# Succeded at 861 with 3 tries
# Succeded at 862 with 7 tries
# Succeded at 863 with 1 tries
# Succeded at 864 with 5 tries
# Succeded at 865 with 9 tries
# Succeded at 866 with 3 tries
# Succeded at 868 with 3 tries
# Succeded at 869 with 4 tries
# Succeded at 870 with 1 tries
# Succeded at 871 with 1 tries
# Succeded at 873 with 3 tries
# Succeded at 874 with 3 tries
# Succeded at 875 with 1 tries
# Succeded at 876 with 1 tries
# Succeded at 877 with 9 tries
# Succeded at 878 with 1 tries
# Succeded at 879 with 3 tries
# Succeded at 881 with 6 tries
# Succeded at 882 with 4 tries
# Succeded at 883 with 1 tries
# Succeded at 884 with 3 tries
# Succeded at 886 with 1 tries
# Succeded at 887 with 10 tries
# Succeded at 888 with 3 tries
# Succeded at 889 with 6 tries
# Succeded at 890 with 3 tries
# Succeded at 891 with 3 tries
# Succeded at 892 with 6 tries
# Succeded at 894 with 1 tries
# Succeded at 896 with 8 tries
# Succeded at 897 with 3 tries
# Succeded at 898 with 3 tries
# Succeded at 899 with 3 tries
# Succeded at 900 with 8 tries
# Succeded at 901 with 3 tries
# Succeded at 902 with 2 tries
# Succeded at 903 with 5 tries
# Succeded at 904 with 3 tries
# Succeded at 905 with 1 tries
# Succeded at 906 with 4 tries
# Succeded at 908 with 3 tries
# Succeded at 909 with 3 tries
# Succeded at 910 with 1 tries
# Succeded at 911 with 4 tries
# Succeded at 912 with 1 tries
# Succeded at 914 with 3 tries
# Succeded at 915 with 3 tries
# Succeded at 916 with 1 tries
# Succeded at 917 with 2 tries
# Succeded at 918 with 3 tries
# Succeded at 920 with 1 tries
# Succeded at 921 with 1 tries
# Succeded at 923 with 3 tries
# Succeded at 924 with 3 tries
# Succeded at 925 with 2 tries
# Succeded at 926 with 1 tries
# Succeded at 927 with 3 tries
# Succeded at 931 with 9 tries
# Succeded at 932 with 9 tries
# Succeded at 933 with 5 tries
# Succeded at 934 with 8 tries
# Succeded at 935 with 1 tries
# Succeded at 936 with 8 tries
# Succeded at 938 with 3 tries
# Succeded at 939 with 8 tries
# Succeded at 940 with 10 tries
# Succeded at 942 with 3 tries
# Succeded at 943 with 2 tries
# Succeded at 944 with 8 tries
# Succeded at 946 with 3 tries
# Succeded at 947 with 3 tries
# Succeded at 949 with 8 tries
# Succeded at 951 with 2 tries
# Succeded at 952 with 1 tries
# Succeded at 953 with 1 tries
# Succeded at 954 with 7 tries
# Succeded at 955 with 1 tries
# Succeded at 957 with 7 tries
# Succeded at 958 with 5 tries
# Succeded at 959 with 1 tries
# Succeded at 960 with 1 tries
# Succeded at 961 with 2 tries
# Succeded at 962 with 3 tries
# Succeded at 963 with 3 tries
# Succeded at 964 with 1 tries
# Succeded at 965 with 10 tries
# Succeded at 967 with 3 tries
# Succeded at 968 with 7 tries
# Succeded at 971 with 3 tries
# Succeded at 972 with 3 tries
# Succeded at 973 with 3 tries
# Succeded at 974 with 3 tries
# Succeded at 975 with 6 tries
# Succeded at 977 with 3 tries
# Succeded at 978 with 3 tries
# Succeded at 979 with 1 tries
# Succeded at 982 with 4 tries
# Succeded at 984 with 1 tries
# Succeded at 986 with 3 tries
# Succeded at 988 with 1 tries
# Succeded at 989 with 7 tries
# Succeded at 990 with 3 tries
# Succeded at 991 with 3 tries
# Succeded at 993 with 2 tries
# Succeded at 996 with 1 tries
# Succeded at 998 with 3 tries
# Succeded at 999 with 3 tries
# Succeded at 1000 with 3 tries
# Succeded at 1001 with 6 tries
# Succeded at 1003 with 7 tries
# Succeded at 1004 with 10 tries
# Succeded at 1005 with 9 tries
# Succeded at 1006 with 5 tries
# Succeded at 1007 with 10 tries
# Succeded at 1008 with 1 tries
# Succeded at 1011 with 3 tries
# Succeded at 1013 with 1 tries
# Succeded at 1014 with 1 tries
# Succeded at 1015 with 1 tries
# Succeded at 1018 with 10 tries
# Succeded at 1020 with 5 tries
# Succeded at 1021 with 8 tries
# Succeded at 1023 with 3 tries
# Succeded at 1024 with 3 tries
# Succeded at 1026 with 3 tries
# Succeded at 1027 with 5 tries
# Succeded at 1028 with 3 tries
# Succeded at 1029 with 9 tries
# Succeded at 1030 with 3 tries
# Succeded at 1032 with 3 tries
# Succeded at 1035 with 3 tries
# Succeded at 1036 with 9 tries
# Succeded at 1037 with 6 tries
# Succeded at 1038 with 5 tries
# Succeded at 1039 with 3 tries
# Succeded at 1040 with 3 tries
# Succeded at 1044 with 1 tries
# Succeded at 1045 with 1 tries
# Succeded at 1046 with 3 tries
# Succeded at 1047 with 3 tries
# Succeded at 1048 with 1 tries
# Succeded at 1049 with 1 tries
# Succeded at 1051 with 8 tries
# Succeded at 1053 with 3 tries
# Succeded at 1054 with 2 tries
# Succeded at 1056 with 7 tries
# Succeded at 1057 with 10 tries
# Succeded at 1058 with 3 tries
# Succeded at 1059 with 3 tries
# Succeded at 1060 with 1 tries
# Succeded at 1061 with 7 tries
# Succeded at 1062 with 1 tries
# Succeded at 1063 with 3 tries
# Succeded at 1065 with 5 tries
# Succeded at 1066 with 1 tries
# Succeded at 1067 with 8 tries
# Succeded at 1068 with 1 tries
# Succeded at 1069 with 1 tries
# Succeded at 1071 with 1 tries
# Succeded at 1073 with 3 tries
# Succeded at 1074 with 6 tries
# Succeded at 1076 with 3 tries
# Succeded at 1077 with 1 tries
# Succeded at 1078 with 6 tries
# Succeded at 1079 with 1 tries
# Succeded at 1080 with 3 tries
# Succeded at 1081 with 3 tries
# Succeded at 1082 with 3 tries
# Succeded at 1084 with 2 tries
# Succeded at 1085 with 1 tries
# Succeded at 1086 with 1 tries
# Succeded at 1088 with 7 tries
# Succeded at 1089 with 6 tries
# Succeded at 1090 with 1 tries
# Succeded at 1091 with 5 tries
# Succeded at 1092 with 3 tries
# Succeded at 1093 with 7 tries
# Succeded at 1094 with 3 tries
# Succeded at 1095 with 6 tries
# Succeded at 1096 with 1 tries
# Succeded at 1097 with 6 tries
# Succeded at 1098 with 3 tries
# Succeded at 1099 with 7 tries
# Succeded at 1100 with 3 tries
# Succeded at 1101 with 1 tries
# Succeded at 1102 with 3 tries
# Succeded at 1103 with 3 tries
# Succeded at 1104 with 3 tries
# Succeded at 1106 with 7 tries
# Succeded at 1107 with 1 tries
# Succeded at 1108 with 2 tries
# Succeded at 1109 with 7 tries
# Succeded at 1110 with 3 tries
# Succeded at 1111 with 3 tries
# Succeded at 1112 with 10 tries
# Succeded at 1113 with 1 tries
# Succeded at 1115 with 5 tries
# Succeded at 1117 with 4 tries
# Succeded at 1118 with 2 tries
# Succeded at 1119 with 1 tries
# Succeded at 1120 with 4 tries
# Succeded at 1121 with 3 tries
# Succeded at 1122 with 4 tries
# Succeded at 1123 with 2 tries
# Succeded at 1124 with 2 tries
# Succeded at 1125 with 7 tries
# Succeded at 1126 with 1 tries
# Succeded at 1128 with 5 tries
# Succeded at 1129 with 2 tries
# Succeded at 1130 with 1 tries
# Succeded at 1131 with 6 tries
# Succeded at 1132 with 2 tries
# Succeded at 1134 with 3 tries
# Succeded at 1135 with 2 tries
# Succeded at 1136 with 2 tries
# Succeded at 1137 with 2 tries
# Succeded at 1139 with 3 tries
# Succeded at 1141 with 3 tries
# Succeded at 1142 with 3 tries
# Succeded at 1143 with 3 tries
# Succeded at 1144 with 3 tries
# Succeded at 1145 with 1 tries
# Succeded at 1146 with 3 tries
# Succeded at 1147 with 1 tries
# Succeded at 1149 with 6 tries
# Succeded at 1151 with 6 tries
# Succeded at 1152 with 3 tries
# Succeded at 1153 with 4 tries
# Succeded at 1154 with 7 tries
# Succeded at 1155 with 3 tries
# Succeded at 1157 with 6 tries
# Succeded at 1158 with 2 tries
# Succeded at 1159 with 7 tries
# Succeded at 1160 with 3 tries
# Succeded at 1161 with 3 tries
# Succeded at 1162 with 2 tries
# Succeded at 1163 with 1 tries
# Succeded at 1164 with 1 tries
# Succeded at 1165 with 3 tries
# Succeded at 1166 with 1 tries
# Succeded at 1167 with 5 tries
# Succeded at 1168 with 7 tries
# Succeded at 1169 with 1 tries
# Succeded at 1170 with 2 tries
# Succeded at 1171 with 5 tries
# Succeded at 1174 with 2 tries
# Succeded at 1175 with 1 tries
# Succeded at 1176 with 10 tries
# Succeded at 1178 with 1 tries
# Succeded at 1180 with 1 tries
# Succeded at 1181 with 3 tries
# Succeded at 1182 with 4 tries
# Succeded at 1183 with 3 tries
# Succeded at 1184 with 4 tries
# Succeded at 1185 with 9 tries
# Succeded at 1186 with 4 tries
# Succeded at 1187 with 1 tries
# Succeded at 1188 with 1 tries
# Succeded at 1189 with 2 tries
# Succeded at 1190 with 9 tries
# Succeded at 1191 with 1 tries
# Succeded at 1193 with 7 tries
# Succeded at 1194 with 3 tries
# Succeded at 1196 with 3 tries
# Succeded at 1198 with 3 tries
# Succeded at 1199 with 3 tries
# Succeded at 1200 with 6 tries
# Succeded at 1201 with 1 tries
# Succeded at 1203 with 1 tries
# Succeded at 1204 with 6 tries
# Succeded at 1205 with 2 tries
# Succeded at 1207 with 9 tries
# Succeded at 1208 with 2 tries
# Succeded at 1209 with 3 tries
# Succeded at 1211 with 3 tries
# Succeded at 1213 with 5 tries
# Succeded at 1216 with 3 tries
# Succeded at 1217 with 1 tries
# Succeded at 1219 with 10 tries
# Succeded at 1220 with 9 tries
# Succeded at 1221 with 6 tries
# Succeded at 1222 with 3 tries
# Succeded at 1223 with 2 tries
# Succeded at 1224 with 3 tries
# Succeded at 1225 with 5 tries
# Succeded at 1226 with 1 tries
# Succeded at 1227 with 1 tries
# Succeded at 1228 with 2 tries
# Succeded at 1229 with 6 tries
# Succeded at 1230 with 1 tries
# Succeded at 1231 with 2 tries
# Succeded at 1232 with 4 tries
# Succeded at 1234 with 5 tries
# Succeded at 1235 with 1 tries
# Succeded at 1236 with 2 tries
# Succeded at 1237 with 3 tries
# Succeded at 1238 with 3 tries
# Succeded at 1239 with 10 tries
# Succeded at 1240 with 1 tries
# Succeded at 1241 with 1 tries
# Succeded at 1242 with 3 tries
# Succeded at 1243 with 4 tries
# Succeded at 1244 with 6 tries
# Succeded at 1247 with 1 tries
# Succeded at 1248 with 7 tries
# Succeded at 1249 with 3 tries
# Succeded at 1251 with 3 tries
# Succeded at 1252 with 1 tries
# Succeded at 1254 with 3 tries
# Succeded at 1255 with 3 tries
# Succeded at 1258 with 3 tries
# Succeded at 1259 with 6 tries
# Succeded at 1260 with 3 tries
# Succeded at 1261 with 2 tries
# Succeded at 1262 with 1 tries
# Succeded at 1264 with 3 tries
# Succeded at 1265 with 1 tries
# Succeded at 1266 with 1 tries
# Succeded at 1268 with 6 tries
# Succeded at 1269 with 3 tries
# Succeded at 1271 with 1 tries
# Succeded at 1272 with 1 tries
# Succeded at 1274 with 3 tries
# Succeded at 1276 with 3 tries
# Succeded at 1277 with 6 tries
# Succeded at 1278 with 10 tries
# Succeded at 1279 with 3 tries
# Succeded at 1280 with 6 tries
# Succeded at 1281 with 1 tries
# Succeded at 1282 with 2 tries
# Succeded at 1283 with 5 tries
# Succeded at 1284 with 3 tries
# Succeded at 1285 with 3 tries
# Succeded at 1286 with 8 tries
# Succeded at 1287 with 7 tries
# Succeded at 1288 with 5 tries
# Succeded at 1290 with 3 tries
# Succeded at 1291 with 4 tries
# Succeded at 1292 with 4 tries
# Succeded at 1293 with 3 tries
# Succeded at 1294 with 2 tries
# Succeded at 1295 with 9 tries
# Succeded at 1296 with 1 tries
# Succeded at 1299 with 1 tries
# Succeded at 1300 with 3 tries
# Succeded at 1301 with 3 tries
# Succeded at 1302 with 1 tries
# Succeded at 1303 with 3 tries
# Succeded at 1304 with 1 tries
# Succeded at 1305 with 8 tries
# Succeded at 1306 with 3 tries
# Succeded at 1307 with 1 tries
# Succeded at 1308 with 3 tries
# Succeded at 1309 with 1 tries
# Succeded at 1311 with 1 tries
# Succeded at 1312 with 7 tries
# Succeded at 1313 with 2 tries
# Succeded at 1314 with 3 tries
# Succeded at 1315 with 3 tries
# Succeded at 1316 with 3 tries
# Succeded at 1317 with 3 tries
# Succeded at 1318 with 1 tries
# Succeded at 1320 with 3 tries
# Succeded at 1323 with 7 tries
# Succeded at 1324 with 3 tries
# Succeded at 1326 with 5 tries
# Succeded at 1329 with 1 tries
# Succeded at 1330 with 1 tries
# Succeded at 1331 with 1 tries
# Succeded at 1333 with 1 tries
# Succeded at 1335 with 3 tries
# Succeded at 1337 with 1 tries
# Succeded at 1338 with 4 tries
# Succeded at 1339 with 1 tries
# Succeded at 1340 with 7 tries
# Succeded at 1341 with 1 tries
# Succeded at 1342 with 1 tries
# Succeded at 1343 with 2 tries
# Succeded at 1345 with 3 tries
# Succeded at 1346 with 3 tries
# Succeded at 1347 with 8 tries
# Succeded at 1348 with 5 tries
# Succeded at 1349 with 5 tries
# Succeded at 1351 with 1 tries
# Succeded at 1352 with 1 tries
# Succeded at 1353 with 5 tries
# Succeded at 1354 with 3 tries
# Succeded at 1355 with 2 tries
# Succeded at 1356 with 5 tries
# Succeded at 1357 with 3 tries
# Succeded at 1360 with 3 tries
# Succeded at 1361 with 1 tries
# Succeded at 1362 with 5 tries
# Succeded at 1363 with 1 tries
# Succeded at 1364 with 1 tries
# Succeded at 1366 with 9 tries
# Succeded at 1367 with 5 tries
# Succeded at 1369 with 1 tries
# Succeded at 1370 with 3 tries
# Succeded at 1371 with 3 tries
# Succeded at 1372 with 1 tries
# Succeded at 1373 with 1 tries
# Succeded at 1374 with 3 tries
# Succeded at 1376 with 1 tries
# Succeded at 1378 with 3 tries
# Succeded at 1379 with 5 tries
# Succeded at 1381 with 3 tries
# Succeded at 1382 with 7 tries
# Succeded at 1383 with 1 tries
# Succeded at 1384 with 1 tries
# Succeded at 1385 with 5 tries
# Succeded at 1386 with 4 tries
# Succeded at 1387 with 10 tries
# Succeded at 1388 with 6 tries
# Succeded at 1389 with 1 tries
# Succeded at 1390 with 8 tries
# Succeded at 1391 with 9 tries
# Succeded at 1393 with 3 tries
# Succeded at 1396 with 1 tries
# Succeded at 1398 with 1 tries
# Succeded at 1399 with 3 tries
# Succeded at 1400 with 2 tries
# Succeded at 1401 with 5 tries
# Succeded at 1402 with 3 tries
# Succeded at 1405 with 6 tries
# Succeded at 1406 with 2 tries
# Succeded at 1407 with 1 tries
# Succeded at 1410 with 4 tries
# Succeded at 1411 with 7 tries
# Succeded at 1412 with 1 tries
# Succeded at 1413 with 4 tries
# Succeded at 1415 with 3 tries
# Succeded at 1417 with 1 tries
# Succeded at 1419 with 1 tries
# Succeded at 1420 with 3 tries
# Succeded at 1421 with 3 tries
# Succeded at 1423 with 3 tries
# Succeded at 1424 with 1 tries
# Succeded at 1425 with 9 tries
# Succeded at 1427 with 10 tries
# Succeded at 1428 with 2 tries
# Succeded at 1429 with 1 tries
# Succeded at 1430 with 3 tries
# Succeded at 1432 with 3 tries
# Succeded at 1435 with 8 tries
# Succeded at 1436 with 3 tries
# Succeded at 1437 with 6 tries
# Succeded at 1438 with 5 tries
# Succeded at 1439 with 1 tries
# Succeded at 1440 with 7 tries
# Succeded at 1441 with 3 tries
# Succeded at 1442 with 1 tries
# Succeded at 1443 with 2 tries
# Succeded at 1444 with 1 tries
# Succeded at 1445 with 3 tries
# Succeded at 1446 with 3 tries
# Succeded at 1448 with 5 tries
# Succeded at 1449 with 2 tries
# Succeded at 1450 with 1 tries
# Succeded at 1451 with 1 tries
# Succeded at 1452 with 3 tries
# Succeded at 1453 with 3 tries
# Succeded at 1454 with 1 tries
# Succeded at 1455 with 1 tries
# Succeded at 1457 with 7 tries
# Succeded at 1458 with 2 tries
# Succeded at 1459 with 6 tries
# Succeded at 1460 with 6 tries
# Succeded at 1463 with 1 tries
# Succeded at 1464 with 5 tries
# Succeded at 1465 with 9 tries
# Succeded at 1467 with 2 tries
# Succeded at 1468 with 3 tries
# Succeded at 1470 with 1 tries
# Succeded at 1471 with 1 tries
# Succeded at 1472 with 7 tries
# Succeded at 1473 with 8 tries
# Succeded at 1474 with 1 tries
# Succeded at 1475 with 1 tries
# Succeded at 1476 with 3 tries
# Succeded at 1477 with 3 tries
# Succeded at 1478 with 2 tries
# Succeded at 1479 with 3 tries
# Succeded at 1480 with 1 tries
# Succeded at 1481 with 3 tries
# Succeded at 1482 with 1 tries
# Succeded at 1483 with 3 tries
# Succeded at 1485 with 5 tries
# Succeded at 1486 with 8 tries
# Succeded at 1488 with 3 tries
# Succeded at 1489 with 9 tries
# Succeded at 1491 with 3 tries
# Succeded at 1492 with 1 tries
# Succeded at 1493 with 3 tries
# Succeded at 1494 with 4 tries
# Succeded at 1496 with 4 tries
# Succeded at 1499 with 8 tries
# Succeded at 1500 with 4 tries
# Succeded at 1502 with 3 tries
# Succeded at 1503 with 7 tries
# Succeded at 1505 with 3 tries
# Succeded at 1506 with 8 tries
# Succeded at 1508 with 3 tries
# Succeded at 1510 with 3 tries
# Succeded at 1512 with 1 tries
# Succeded at 1513 with 3 tries
# Succeded at 1514 with 1 tries
# Succeded at 1515 with 8 tries
# Succeded at 1516 with 4 tries
# Succeded at 1517 with 3 tries
# Succeded at 1518 with 5 tries
# Succeded at 1521 with 4 tries
# Succeded at 1522 with 6 tries
# Succeded at 1523 with 1 tries
# Succeded at 1525 with 3 tries
# Succeded at 1526 with 1 tries
# Succeded at 1527 with 3 tries
# Succeded at 1528 with 5 tries
# Succeded at 1530 with 5 tries
# Succeded at 1533 with 1 tries
# Succeded at 1534 with 1 tries
# Succeded at 1535 with 2 tries
# Succeded at 1536 with 5 tries
# Succeded at 1537 with 1 tries
# Succeded at 1540 with 6 tries
# Succeded at 1541 with 3 tries
# Succeded at 1542 with 9 tries
# Succeded at 1544 with 3 tries
# Succeded at 1545 with 10 tries
# Succeded at 1547 with 2 tries
# Succeded at 1548 with 8 tries
# Succeded at 1549 with 5 tries
# Succeded at 1550 with 3 tries
# Succeded at 1551 with 1 tries
# Succeded at 1552 with 1 tries
# Succeded at 1553 with 1 tries
# Succeded at 1554 with 1 tries
# Succeded at 1555 with 7 tries
# Succeded at 1556 with 2 tries
# Succeded at 1557 with 3 tries
# Succeded at 1558 with 5 tries
# Succeded at 1559 with 3 tries
# Succeded at 1560 with 3 tries
# Succeded at 1563 with 3 tries
# Succeded at 1564 with 4 tries
# Succeded at 1565 with 1 tries
# Succeded at 1566 with 1 tries
# Succeded at 1570 with 5 tries
# Succeded at 1571 with 3 tries
# Succeded at 1572 with 3 tries
# Succeded at 1573 with 5 tries
# Succeded at 1574 with 3 tries
# Succeded at 1575 with 1 tries
# Succeded at 1576 with 5 tries
# Succeded at 1577 with 10 tries
# Succeded at 1578 with 5 tries
# Succeded at 1579 with 1 tries
# Succeded at 1580 with 1 tries
# Succeded at 1581 with 3 tries
# Succeded at 1582 with 10 tries
# Succeded at 1584 with 8 tries
# Succeded at 1585 with 1 tries
# Succeded at 1586 with 10 tries
# Succeded at 1587 with 2 tries
# Succeded at 1589 with 3 tries
# Succeded at 1590 with 7 tries
# Succeded at 1591 with 1 tries
# Succeded at 1593 with 1 tries
# Succeded at 1594 with 4 tries
# Succeded at 1595 with 3 tries
# Succeded at 1596 with 5 tries
# Succeded at 1599 with 1 tries
# Succeded at 1600 with 2 tries
# Succeded at 1601 with 2 tries
# Succeded at 1602 with 10 tries
# Succeded at 1603 with 1 tries
# Succeded at 1604 with 2 tries
# Succeded at 1606 with 6 tries
# Succeded at 1607 with 3 tries
# Succeded at 1610 with 3 tries
# Succeded at 1611 with 10 tries
# Succeded at 1612 with 3 tries
# Succeded at 1613 with 3 tries
# Succeded at 1614 with 1 tries
# Succeded at 1615 with 3 tries
# Succeded at 1617 with 1 tries
# Succeded at 1618 with 3 tries
# Succeded at 1619 with 2 tries
# Succeded at 1620 with 1 tries
# Succeded at 1621 with 1 tries
# Succeded at 1622 with 9 tries
# Succeded at 1623 with 10 tries
# Succeded at 1624 with 1 tries
# Succeded at 1626 with 6 tries
# Succeded at 1627 with 7 tries
# Succeded at 1628 with 1 tries
# Succeded at 1629 with 5 tries
# Succeded at 1630 with 8 tries
# Succeded at 1631 with 1 tries
# Succeded at 1632 with 4 tries
# Succeded at 1633 with 3 tries
# Succeded at 1635 with 7 tries
# Succeded at 1636 with 3 tries
# Succeded at 1637 with 5 tries
# Succeded at 1639 with 3 tries
# Succeded at 1640 with 3 tries
# Succeded at 1641 with 1 tries
# Succeded at 1642 with 3 tries
# Succeded at 1644 with 2 tries
# Succeded at 1645 with 7 tries
# Succeded at 1646 with 1 tries
# Succeded at 1647 with 3 tries
# Succeded at 1652 with 1 tries
# Succeded at 1653 with 3 tries
# Succeded at 1655 with 8 tries
# Succeded at 1657 with 3 tries
# Succeded at 1658 with 3 tries
# Succeded at 1661 with 3 tries
# Succeded at 1662 with 4 tries
# Succeded at 1663 with 5 tries
# Succeded at 1665 with 1 tries
# Succeded at 1666 with 8 tries
# Succeded at 1667 with 1 tries
# Succeded at 1668 with 2 tries
# Succeded at 1669 with 1 tries
# Succeded at 1670 with 3 tries
# Succeded at 1671 with 10 tries
# Succeded at 1673 with 4 tries
# Succeded at 1674 with 4 tries
# Succeded at 1675 with 8 tries
# Succeded at 1676 with 4 tries
# Succeded at 1677 with 4 tries
# Succeded at 1678 with 3 tries
# Succeded at 1679 with 3 tries
# Succeded at 1681 with 5 tries
# Succeded at 1682 with 1 tries
# Succeded at 1684 with 10 tries
# Succeded at 1685 with 3 tries
# Succeded at 1686 with 3 tries
# Succeded at 1687 with 1 tries
# Succeded at 1688 with 3 tries
# Succeded at 1689 with 3 tries
# Succeded at 1693 with 4 tries
# Succeded at 1695 with 1 tries
# Succeded at 1696 with 3 tries
# Succeded at 1697 with 3 tries
# Succeded at 1698 with 2 tries
# Succeded at 1699 with 3 tries
# Succeded at 1700 with 5 tries
# Succeded at 1701 with 3 tries
# Succeded at 1703 with 8 tries
# Succeded at 1705 with 3 tries
# Succeded at 1707 with 3 tries
# Succeded at 1708 with 3 tries
# Succeded at 1709 with 3 tries
# Succeded at 1711 with 9 tries
# Succeded at 1712 with 1 tries
# Succeded at 1714 with 3 tries
# Succeded at 1715 with 6 tries
# Succeded at 1717 with 1 tries
# Succeded at 1718 with 6 tries
# Succeded at 1719 with 9 tries
# Succeded at 1720 with 3 tries
# Succeded at 1722 with 3 tries
# Succeded at 1723 with 2 tries
# Succeded at 1724 with 1 tries
# Succeded at 1726 with 3 tries
# Succeded at 1727 with 3 tries
# Succeded at 1728 with 1 tries
# Succeded at 1729 with 3 tries
# Succeded at 1730 with 4 tries
# Succeded at 1731 with 3 tries
# Succeded at 1732 with 1 tries
# Succeded at 1733 with 3 tries
# Succeded at 1734 with 2 tries
# Succeded at 1736 with 1 tries
# Succeded at 1737 with 3 tries
# Succeded at 1738 with 1 tries
# Succeded at 1739 with 2 tries
# Succeded at 1740 with 2 tries
# Succeded at 1742 with 3 tries
# Succeded at 1743 with 1 tries
# Succeded at 1744 with 8 tries
# Succeded at 1745 with 2 tries
# Succeded at 1746 with 1 tries
# Succeded at 1747 with 3 tries
# Succeded at 1749 with 7 tries
# Succeded at 1750 with 3 tries
# mosek failed at
# Succeded at 1751 with 5 tries
# Succeded at 1752 with 3 tries
# Succeded at 1754 with 1 tries
# Succeded at 1755 with 1 tries
# Succeded at 1756 with 9 tries
# Succeded at 1757 with 3 tries
# Succeded at 1758 with 6 tries
# Succeded at 1761 with 6 tries
# Succeded at 1764 with 6 tries
# Succeded at 1767 with 4 tries
# Succeded at 1768 with 3 tries
# Succeded at 1769 with 3 tries
# Succeded at 1771 with 7 tries
# Succeded at 1772 with 3 tries
# Succeded at 1774 with 8 tries
# Succeded at 1775 with 2 tries
# Succeded at 1776 with 3 tries
# Succeded at 1777 with 1 tries
# Succeded at 1778 with 3 tries
# Succeded at 1779 with 3 tries
# Succeded at 1780 with 7 tries
# Succeded at 1781 with 1 tries
# Succeded at 1782 with 3 tries
# Succeded at 1783 with 6 tries
# Succeded at 1785 with 8 tries
# Succeded at 1787 with 2 tries
# Succeded at 1788 with 3 tries
# Succeded at 1789 with 1 tries
# Succeded at 1790 with 1 tries
# Succeded at 1791 with 4 tries
# Succeded at 1792 with 3 tries
# Succeded at 1793 with 10 tries
# Succeded at 1794 with 5 tries
# Succeded at 1795 with 2 tries
# Succeded at 1796 with 3 tries
# Succeded at 1797 with 4 tries
# Succeded at 1798 with 3 tries
# Succeded at 1799 with 7 tries
# Succeded at 1800 with 5 tries
# Succeded at 1802 with 3 tries
# Succeded at 1804 with 1 tries
# Succeded at 1805 with 1 tries
# Succeded at 1806 with 1 tries
# Succeded at 1807 with 8 tries
# Succeded at 1809 with 6 tries
# Succeded at 1811 with 2 tries
# Succeded at 1812 with 4 tries
# Succeded at 1813 with 1 tries
# Succeded at 1814 with 1 tries
# Succeded at 1817 with 7 tries
# Succeded at 1818 with 3 tries
# Succeded at 1819 with 1 tries
# Succeded at 1821 with 2 tries
# Succeded at 1822 with 4 tries
# Succeded at 1823 with 4 tries
# Succeded at 1824 with 1 tries
# Succeded at 1825 with 1 tries
# Succeded at 1826 with 7 tries
# Succeded at 1827 with 3 tries
# Succeded at 1828 with 6 tries
# Succeded at 1829 with 3 tries
# Succeded at 1830 with 1 tries
# Succeded at 1831 with 2 tries
# Succeded at 1833 with 3 tries
# Succeded at 1834 with 2 tries
# Succeded at 1836 with 1 tries
# Succeded at 1837 with 3 tries
# Succeded at 1838 with 1 tries
# Succeded at 1839 with 5 tries
# Succeded at 1840 with 3 tries
# Succeded at 1841 with 3 tries
# Succeded at 1842 with 3 tries
# Succeded at 1843 with 6 tries
# Succeded at 1844 with 3 tries
# Succeded at 1845 with 9 tries
# Succeded at 1846 with 3 tries
# Succeded at 1847 with 3 tries
# Succeded at 1848 with 1 tries
# Succeded at 1849 with 3 tries
# Succeded at 1850 with 1 tries
# Succeded at 1851 with 1 tries
# Succeded at 1852 with 3 tries
# Succeded at 1853 with 3 tries
# Succeded at 1854 with 3 tries
# Succeded at 1855 with 10 tries
# Succeded at 1856 with 1 tries
# Succeded at 1857 with 3 tries
# Succeded at 1858 with 6 tries
# Succeded at 1859 with 1 tries
# Succeded at 1860 with 4 tries
# Succeded at 1861 with 3 tries
# Succeded at 1862 with 1 tries
# Succeded at 1863 with 4 tries
# Succeded at 1864 with 1 tries
# Succeded at 1867 with 4 tries
# Succeded at 1868 with 3 tries
# Succeded at 1869 with 10 tries
# Succeded at 1870 with 9 tries
# Succeded at 1872 with 5 tries
# Succeded at 1873 with 3 tries
# Succeded at 1877 with 1 tries
# Succeded at 1878 with 3 tries
# Succeded at 1879 with 2 tries
# Succeded at 1880 with 7 tries
# Succeded at 1881 with 3 tries
# Succeded at 1882 with 1 tries
# Succeded at 1883 with 2 tries
# Succeded at 1884 with 1 tries
# Succeded at 1885 with 4 tries
# Succeded at 1887 with 7 tries
# Succeded at 1888 with 1 tries
# Succeded at 1889 with 1 tries
# Succeded at 1890 with 3 tries
# Succeded at 1891 with 1 tries
# Succeded at 1892 with 3 tries
# Succeded at 1893 with 7 tries
# Succeded at 1894 with 5 tries
# Succeded at 1896 with 3 tries
# Succeded at 1898 with 10 tries
# Succeded at 1900 with 1 tries
# mosek failed at
# Succeded at 1901 with 2 tries
# Succeded at 1902 with 3 tries
# Succeded at 1903 with 4 tries
# Succeded at 1904 with 6 tries
# Succeded at 1905 with 1 tries
# Succeded at 1906 with 1 tries
# Succeded at 1907 with 8 tries
# Succeded at 1909 with 7 tries
# Succeded at 1910 with 9 tries
# Succeded at 1911 with 1 tries
# Succeded at 1912 with 1 tries
# Succeded at 1913 with 2 tries
# Succeded at 1914 with 1 tries
# Succeded at 1915 with 10 tries
# Succeded at 1916 with 3 tries
# Succeded at 1917 with 10 tries
# Succeded at 1918 with 3 tries
# Succeded at 1919 with 1 tries
# Succeded at 1920 with 7 tries
# Succeded at 1921 with 1 tries
# Succeded at 1922 with 3 tries
# Succeded at 1925 with 10 tries
# Succeded at 1926 with 3 tries
# Succeded at 1929 with 3 tries
# Succeded at 1930 with 10 tries
# Succeded at 1931 with 6 tries
# Succeded at 1933 with 7 tries
# Succeded at 1934 with 2 tries
# Succeded at 1935 with 4 tries
# Succeded at 1936 with 6 tries
# Succeded at 1937 with 3 tries
# Succeded at 1938 with 4 tries
# Succeded at 1939 with 3 tries
# Succeded at 1940 with 3 tries
# Succeded at 1941 with 1 tries
# Succeded at 1942 with 2 tries
# Succeded at 1943 with 3 tries
# Succeded at 1944 with 1 tries
# Succeded at 1947 with 9 tries
# Succeded at 1948 with 1 tries
# Succeded at 1949 with 3 tries
# Succeded at 1950 with 4 tries
# Succeded at 1952 with 2 tries
# Succeded at 1953 with 3 tries
# mosek failed at
# Succeded at 1955 with 2 tries
# Succeded at 1956 with 1 tries
# Succeded at 1958 with 6 tries
# Succeded at 1959 with 1 tries
# Succeded at 1960 with 6 tries
# Succeded at 1961 with 3 tries
# Succeded at 1962 with 3 tries
# Succeded at 1963 with 10 tries
# Succeded at 1967 with 1 tries
# Succeded at 1968 with 1 tries
# Succeded at 1969 with 2 tries
# Succeded at 1970 with 9 tries
# Succeded at 1971 with 1 tries
# Succeded at 1972 with 10 tries
# Succeded at 1973 with 3 tries
# Succeded at 1974 with 6 tries
# Succeded at 1975 with 3 tries
# Succeded at 1977 with 4 tries
# Succeded at 1978 with 9 tries
# Succeded at 1979 with 5 tries
# Succeded at 1980 with 3 tries
# Succeded at 1981 with 1 tries
# Succeded at 1982 with 5 tries
# Succeded at 1984 with 3 tries
# Succeded at 1985 with 1 tries
# Succeded at 1986 with 3 tries
# Succeded at 1988 with 1 tries
# Succeded at 1990 with 3 tries
# Succeded at 1991 with 1 tries
# Succeded at 1992 with 3 tries
# Succeded at 1993 with 2 tries
# Succeded at 1994 with 2 tries
# Succeded at 1995 with 3 tries
# Succeded at 1997 with 7 tries
# Succeded at 1998 with 3 tries
# Succeded at 1999 with 3 tries
# Succeded at 2000 with 6 tries
# Succeded at 2001 with 3 tries
# Succeded at 2002 with 6 tries
# Succeded at 2003 with 10 tries
# Succeded at 2004 with 1 tries
# Succeded at 2005 with 3 tries
# Succeded at 2006 with 3 tries
# Succeded at 2007 with 7 tries
# Succeded at 2009 with 1 tries
# Succeded at 2010 with 1 tries
# Succeded at 2011 with 2 tries
# Succeded at 2012 with 7 tries
# Succeded at 2013 with 3 tries
# Succeded at 2014 with 6 tries
# Succeded at 2015 with 9 tries
# Succeded at 2017 with 3 tries
# Succeded at 2018 with 3 tries
# Succeded at 2019 with 1 tries
# Succeded at 2020 with 3 tries
# Succeded at 2021 with 5 tries
# Succeded at 2022 with 3 tries
# Succeded at 2023 with 1 tries
# Succeded at 2024 with 2 tries
# Succeded at 2025 with 3 tries
# Succeded at 2026 with 1 tries
# Succeded at 2027 with 3 tries
# Succeded at 2028 with 1 tries
# Succeded at 2029 with 7 tries
# Succeded at 2030 with 6 tries
# Succeded at 2031 with 6 tries
# Succeded at 2033 with 2 tries
# Succeded at 2034 with 3 tries
# Succeded at 2036 with 1 tries
# Succeded at 2037 with 1 tries
# Succeded at 2038 with 2 tries
# Succeded at 2039 with 2 tries
# Succeded at 2040 with 10 tries
# Succeded at 2041 with 2 tries
# Succeded at 2042 with 4 tries
# Succeded at 2043 with 10 tries
# Succeded at 2044 with 8 tries
# Succeded at 2047 with 3 tries
# Succeded at 2049 with 7 tries
# Succeded at 2050 with 3 tries
# Succeded at 2051 with 3 tries
# Succeded at 2053 with 9 tries
# Succeded at 2054 with 8 tries
# Succeded at 2056 with 3 tries
# Succeded at 2059 with 3 tries
# Succeded at 2060 with 1 tries
# Succeded at 2061 with 5 tries
# Succeded at 2063 with 3 tries
# Succeded at 2064 with 8 tries
# Succeded at 2065 with 2 tries
# Succeded at 2066 with 1 tries
# Succeded at 2067 with 1 tries
# Succeded at 2068 with 1 tries
# Succeded at 2069 with 1 tries
# Succeded at 2070 with 1 tries
# Succeded at 2071 with 7 tries
# Succeded at 2072 with 3 tries
# Succeded at 2073 with 1 tries
# Succeded at 2075 with 4 tries
# Succeded at 2076 with 4 tries
# Succeded at 2077 with 8 tries
# Succeded at 2079 with 4 tries
# Succeded at 2081 with 9 tries
# Succeded at 2084 with 3 tries
# Succeded at 2086 with 9 tries
# Succeded at 2087 with 1 tries
# Succeded at 2088 with 5 tries
# Succeded at 2092 with 3 tries
# mosek failed at
# Succeded at 2096 with 3 tries
# Succeded at 2097 with 8 tries
# Succeded at 2098 with 1 tries
# Succeded at 2100 with 1 tries
# Succeded at 2101 with 4 tries
# Succeded at 2102 with 3 tries
# Succeded at 2103 with 3 tries
# Succeded at 2104 with 1 tries
# Succeded at 2105 with 1 tries
# Succeded at 2106 with 3 tries
# Succeded at 2107 with 7 tries
# Succeded at 2108 with 1 tries
# Succeded at 2109 with 3 tries
# Succeded at 2110 with 6 tries
# Succeded at 2112 with 3 tries
# Succeded at 2113 with 1 tries
# Succeded at 2114 with 3 tries
# Succeded at 2115 with 1 tries
# Succeded at 2116 with 5 tries
# Succeded at 2117 with 2 tries
# Succeded at 2118 with 1 tries
# Succeded at 2119 with 7 tries
# Succeded at 2120 with 2 tries
# ...
# Succeded at 9318 with 3 tries
# Succeded at 9319 with 3 tries
# Succeded at 9320 with 1 tries
# Succeded at 9321 with 3 tries
# Succeded at 9322 with 4 tries
# Succeded at 9323 with 3 tries
# Succeded at 9325 with 1 tries
# Succeded at 9326 with 1 tries
# Succeded at 9327 with 3 tries
# Succeded at 9328 with 1 tries
# Succeded at 9330 with 5 tries
# Succeded at 9333 with 1 tries
# Succeded at 9334 with 1 tries
# Succeded at 9335 with 3 tries
# Succeded at 9336 with 1 tries
# Succeded at 9337 with 1 tries
# Succeded at 9338 with 3 tries
# Succeded at 9339 with 4 tries
# Succeded at 9340 with 3 tries
# Succeded at 9341 with 4 tries
# Succeded at 9342 with 3 tries
# Succeded at 9343 with 4 tries
# Succeded at 9345 with 2 tries
# Succeded at 9346 with 1 tries
# Succeded at 9347 with 1 tries
# Succeded at 9348 with 3 tries
# Succeded at 9349 with 3 tries
# Succeded at 9351 with 3 tries
# Succeded at 9352 with 1 tries
# Succeded at 9353 with 1 tries
# Succeded at 9354 with 2 tries
# Succeded at 9355 with 3 tries
# Succeded at 9356 with 2 tries
# Succeded at 9357 with 8 tries
# Succeded at 9358 with 9 tries
# Succeded at 9359 with 1 tries
# Succeded at 9361 with 1 tries
# Succeded at 9362 with 7 tries
# Succeded at 9363 with 3 tries
# Succeded at 9364 with 9 tries
# Succeded at 9365 with 1 tries
# Succeded at 9366 with 6 tries
# Succeded at 9367 with 3 tries
# Succeded at 9368 with 2 tries
# Succeded at 9369 with 5 tries
# Succeded at 9370 with 5 tries
# Succeded at 9371 with 1 tries
# Succeded at 9372 with 6 tries
# Succeded at 9373 with 3 tries
# Succeded at 9374 with 1 tries
# Succeded at 9375 with 2 tries
# Succeded at 9377 with 5 tries
# Succeded at 9378 with 3 tries
# Succeded at 9379 with 6 tries
# Succeded at 9380 with 5 tries
# Succeded at 9381 with 3 tries
# Succeded at 9382 with 3 tries
# Succeded at 9383 with 4 tries
# Succeded at 9384 with 7 tries
# Succeded at 9385 with 1 tries
# Succeded at 9386 with 5 tries
# Succeded at 9388 with 1 tries
# Succeded at 9391 with 3 tries
# Succeded at 9393 with 2 tries
# Succeded at 9394 with 2 tries
# Succeded at 9396 with 1 tries
# Succeded at 9397 with 2 tries
# Succeded at 9398 with 4 tries
# Succeded at 9399 with 2 tries
# Succeded at 9401 with 3 tries
# Succeded at 9402 with 1 tries
# Succeded at 9404 with 9 tries
# Succeded at 9405 with 6 tries
# Succeded at 9406 with 2 tries
# Succeded at 9407 with 9 tries
# Succeded at 9408 with 4 tries
# Succeded at 9409 with 2 tries
# Succeded at 9411 with 7 tries
# Succeded at 9412 with 3 tries
# Succeded at 9414 with 4 tries
# Succeded at 9415 with 4 tries
# Succeded at 9416 with 8 tries
# Succeded at 9417 with 2 tries
# Succeded at 9418 with 2 tries
# Succeded at 9419 with 7 tries
# Succeded at 9420 with 1 tries
# Succeded at 9421 with 3 tries
# Succeded at 9422 with 3 tries
# Succeded at 9424 with 3 tries
# Succeded at 9426 with 3 tries
# Succeded at 9427 with 5 tries
# Succeded at 9429 with 6 tries
# Succeded at 9430 with 3 tries
# Succeded at 9432 with 1 tries
# Succeded at 9433 with 1 tries
# Succeded at 9434 with 4 tries
# Succeded at 9435 with 3 tries
# Succeded at 9436 with 2 tries
# Succeded at 9437 with 5 tries
# Succeded at 9438 with 1 tries
# Succeded at 9439 with 3 tries
# Succeded at 9440 with 1 tries
# Succeded at 9442 with 7 tries
# Succeded at 9443 with 3 tries
# Succeded at 9444 with 8 tries
# Succeded at 9445 with 3 tries
# Succeded at 9447 with 3 tries
# Succeded at 9448 with 1 tries
# Succeded at 9450 with 5 tries
# Succeded at 9451 with 8 tries
# Succeded at 9452 with 3 tries
# Succeded at 9453 with 5 tries
# Succeded at 9454 with 3 tries
# Succeded at 9455 with 1 tries
# Succeded at 9457 with 3 tries
# Succeded at 9458 with 2 tries
# Succeded at 9459 with 2 tries
# Succeded at 9460 with 1 tries
# Succeded at 9461 with 3 tries
# Succeded at 9462 with 3 tries
# Succeded at 9464 with 3 tries
# Succeded at 9465 with 4 tries
# Succeded at 9466 with 3 tries
# Succeded at 9467 with 2 tries
# Succeded at 9470 with 3 tries
# Succeded at 9472 with 6 tries
# Succeded at 9474 with 2 tries
# Succeded at 9476 with 6 tries
# Succeded at 9477 with 1 tries
# mosek failed at
# Succeded at 9479 with 8 tries
# Succeded at 9480 with 5 tries
# Succeded at 9481 with 1 tries
# Succeded at 9482 with 1 tries
# Succeded at 9483 with 3 tries
# Succeded at 9484 with 3 tries
# Succeded at 9485 with 4 tries
# Succeded at 9486 with 5 tries
# Succeded at 9489 with 1 tries
# Succeded at 9490 with 1 tries
# Succeded at 9493 with 3 tries
# Succeded at 9495 with 3 tries
# Succeded at 9497 with 2 tries
# Succeded at 9498 with 8 tries
# Succeded at 9500 with 4 tries
# Succeded at 9501 with 5 tries
# Succeded at 9502 with 1 tries
# Succeded at 9503 with 6 tries
# Succeded at 9504 with 3 tries
# Succeded at 9505 with 4 tries
# mosek failed at
# Succeded at 9508 with 4 tries
# Succeded at 9509 with 7 tries
# Succeded at 9510 with 4 tries
# Succeded at 9511 with 8 tries
# Succeded at 9512 with 1 tries
# Succeded at 9513 with 8 tries
# Succeded at 9514 with 3 tries
# Succeded at 9515 with 2 tries
# Succeded at 9516 with 7 tries
# Succeded at 9517 with 4 tries
# Succeded at 9518 with 1 tries
# Succeded at 9519 with 7 tries
# Succeded at 9520 with 4 tries
# Succeded at 9521 with 3 tries
# Succeded at 9522 with 1 tries
# Succeded at 9523 with 3 tries
# Succeded at 9524 with 1 tries
# Succeded at 9530 with 3 tries
# Succeded at 9532 with 2 tries
# Succeded at 9533 with 3 tries
# Succeded at 9534 with 1 tries
# Succeded at 9535 with 10 tries
# Succeded at 9536 with 3 tries
# Succeded at 9537 with 3 tries
# Succeded at 9538 with 9 tries
# Succeded at 9540 with 3 tries
# Succeded at 9542 with 3 tries
# Succeded at 9543 with 8 tries
# Succeded at 9545 with 2 tries
# Succeded at 9546 with 5 tries
# Succeded at 9547 with 9 tries
# Succeded at 9548 with 8 tries
# Succeded at 9549 with 1 tries
# Succeded at 9551 with 1 tries
# Succeded at 9552 with 1 tries
# Succeded at 9553 with 5 tries
# Succeded at 9554 with 9 tries
# Succeded at 9557 with 3 tries
# Succeded at 9558 with 1 tries
# Succeded at 9559 with 1 tries
# Succeded at 9560 with 3 tries
# Succeded at 9563 with 2 tries
# Succeded at 9564 with 3 tries
# Succeded at 9566 with 7 tries
# Succeded at 9569 with 1 tries
# Succeded at 9572 with 1 tries
# Succeded at 9573 with 3 tries
# Succeded at 9574 with 3 tries
# Succeded at 9575 with 1 tries
# Succeded at 9579 with 3 tries
# Succeded at 9580 with 7 tries
# Succeded at 9581 with 3 tries
# Succeded at 9582 with 3 tries
# Succeded at 9583 with 1 tries
# Succeded at 9584 with 3 tries
# Succeded at 9586 with 3 tries
# Succeded at 9587 with 3 tries
# Succeded at 9588 with 10 tries
# Succeded at 9590 with 1 tries
# Succeded at 9591 with 3 tries
# Succeded at 9593 with 7 tries
# Succeded at 9596 with 3 tries
# Succeded at 9597 with 3 tries
# Succeded at 9600 with 2 tries
# Succeded at 9601 with 3 tries
# Succeded at 9602 with 1 tries
# Succeded at 9603 with 4 tries
# Succeded at 9604 with 1 tries
# Succeded at 9605 with 3 tries
# Succeded at 9606 with 3 tries
# Succeded at 9608 with 4 tries
# Succeded at 9611 with 1 tries
# Succeded at 9613 with 1 tries
# Succeded at 9615 with 3 tries
# Succeded at 9616 with 2 tries
# Succeded at 9617 with 5 tries
# Succeded at 9619 with 1 tries
# Succeded at 9621 with 3 tries
# Succeded at 9622 with 5 tries
# Succeded at 9623 with 6 tries
# Succeded at 9624 with 5 tries
# Succeded at 9625 with 3 tries
# Succeded at 9626 with 1 tries
# Succeded at 9627 with 5 tries
# Succeded at 9630 with 1 tries
# Succeded at 9631 with 2 tries
# Succeded at 9632 with 7 tries
# Succeded at 9633 with 2 tries
# Succeded at 9634 with 10 tries
# Succeded at 9636 with 4 tries
# Succeded at 9639 with 4 tries
# Succeded at 9640 with 3 tries
# Succeded at 9641 with 2 tries
# Succeded at 9643 with 7 tries
# Succeded at 9645 with 3 tries
# Succeded at 9647 with 5 tries
# Succeded at 9648 with 3 tries
# Succeded at 9649 with 6 tries
# Succeded at 9650 with 3 tries
# Succeded at 9653 with 3 tries
# Succeded at 9654 with 2 tries
# Succeded at 9655 with 4 tries
# Succeded at 9656 with 4 tries
# Succeded at 9657 with 3 tries
# Succeded at 9658 with 1 tries
# Succeded at 9659 with 9 tries
# Succeded at 9660 with 6 tries
# Succeded at 9661 with 5 tries
# Succeded at 9662 with 5 tries
# Succeded at 9663 with 9 tries
# Succeded at 9664 with 6 tries
# Succeded at 9665 with 1 tries
# Succeded at 9666 with 8 tries
# Succeded at 9669 with 1 tries
# Succeded at 9670 with 5 tries
# Succeded at 9671 with 3 tries
# Succeded at 9672 with 5 tries
# Succeded at 9674 with 7 tries
# Succeded at 9675 with 1 tries
# Succeded at 9676 with 2 tries
# Succeded at 9678 with 3 tries
# Succeded at 9679 with 3 tries
# Succeded at 9680 with 6 tries
# Succeded at 9681 with 1 tries
# Succeded at 9682 with 3 tries
# Succeded at 9684 with 5 tries
# Succeded at 9687 with 6 tries
# Succeded at 9688 with 3 tries
# Succeded at 9689 with 3 tries
# Succeded at 9690 with 2 tries
# Succeded at 9692 with 5 tries
# Succeded at 9693 with 1 tries
# Succeded at 9695 with 8 tries
# Succeded at 9696 with 1 tries
# Succeded at 9697 with 6 tries
# Succeded at 9698 with 3 tries
# Succeded at 9699 with 4 tries
# Succeded at 9700 with 3 tries
# Succeded at 9701 with 3 tries
# Succeded at 9702 with 4 tries
# Succeded at 9703 with 3 tries
# Succeded at 9704 with 1 tries
# Succeded at 9705 with 7 tries
# Succeded at 9706 with 9 tries
# Succeded at 9707 with 1 tries
# Succeded at 9708 with 7 tries
# Succeded at 9709 with 1 tries
# Succeded at 9710 with 5 tries
# Succeded at 9711 with 8 tries
# Succeded at 9712 with 10 tries
# Succeded at 9713 with 1 tries
# Succeded at 9714 with 2 tries
# Succeded at 9715 with 3 tries
# Succeded at 9716 with 10 tries
# Succeded at 9717 with 6 tries
# Succeded at 9718 with 3 tries
# Succeded at 9721 with 2 tries
# Succeded at 9722 with 1 tries
# Succeded at 9723 with 5 tries
# Succeded at 9724 with 2 tries
# Succeded at 9725 with 3 tries
# Succeded at 9726 with 2 tries
# Succeded at 9727 with 2 tries
# mosek failed at
# Succeded at 9729 with 7 tries
# Succeded at 9730 with 1 tries
# Succeded at 9732 with 2 tries
# Succeded at 9733 with 3 tries
# Succeded at 9734 with 1 tries
# Succeded at 9736 with 3 tries
# Succeded at 9738 with 3 tries
# Succeded at 9741 with 1 tries
# Succeded at 9742 with 1 tries
# Succeded at 9744 with 1 tries
# Succeded at 9745 with 3 tries
# Succeded at 9746 with 9 tries
# Succeded at 9747 with 2 tries
# Succeded at 9748 with 3 tries
# Succeded at 9749 with 8 tries
# Succeded at 9750 with 1 tries
# Succeded at 9751 with 1 tries
# Succeded at 9752 with 1 tries
# Succeded at 9753 with 2 tries
# Succeded at 9754 with 1 tries
# Succeded at 9756 with 1 tries
# Succeded at 9757 with 1 tries
# Succeded at 9758 with 1 tries
# Succeded at 9760 with 8 tries
# Succeded at 9762 with 2 tries
# Succeded at 9763 with 3 tries
# Succeded at 9764 with 1 tries
# Succeded at 9765 with 7 tries
# Succeded at 9767 with 1 tries
# Succeded at 9768 with 1 tries
# Succeded at 9770 with 1 tries
# Succeded at 9771 with 1 tries
# Succeded at 9772 with 1 tries
# Succeded at 9774 with 4 tries
# Succeded at 9775 with 2 tries
# Succeded at 9776 with 3 tries
# Succeded at 9777 with 3 tries
# Succeded at 9778 with 3 tries
# Succeded at 9779 with 2 tries
# Succeded at 9780 with 3 tries
# Succeded at 9781 with 3 tries
# Succeded at 9782 with 3 tries
# Succeded at 9784 with 6 tries
# Succeded at 9785 with 1 tries
# Succeded at 9787 with 9 tries
# Succeded at 9788 with 3 tries
# Succeded at 9789 with 4 tries
# Succeded at 9790 with 5 tries
# Succeded at 9791 with 3 tries
# Succeded at 9793 with 1 tries
# Succeded at 9795 with 3 tries
# Succeded at 9796 with 1 tries
# Succeded at 9797 with 3 tries
# Succeded at 9799 with 3 tries
# Succeded at 9800 with 3 tries
# Succeded at 9801 with 4 tries
# Succeded at 9805 with 5 tries
# Succeded at 9806 with 10 tries
# Succeded at 9807 with 2 tries
# Succeded at 9808 with 1 tries
# Succeded at 9809 with 2 tries
# Succeded at 9810 with 4 tries
# Succeded at 9811 with 3 tries
# Succeded at 9813 with 3 tries
# Succeded at 9814 with 1 tries
# Succeded at 9815 with 9 tries
# Succeded at 9816 with 1 tries
# Succeded at 9817 with 5 tries
# Succeded at 9819 with 3 tries
# Succeded at 9820 with 10 tries
# Succeded at 9821 with 2 tries
# Succeded at 9822 with 3 tries
# Succeded at 9824 with 9 tries
# Succeded at 9825 with 8 tries
# Succeded at 9826 with 3 tries
# Succeded at 9827 with 8 tries
# Succeded at 9828 with 3 tries
# Succeded at 9829 with 3 tries
# Succeded at 9830 with 4 tries
# Succeded at 9831 with 1 tries
# Succeded at 9834 with 6 tries
# Succeded at 9836 with 3 tries
# Succeded at 9837 with 1 tries
# Succeded at 9839 with 1 tries
# Succeded at 9840 with 1 tries
# Succeded at 9841 with 1 tries
# Succeded at 9843 with 3 tries
# Succeded at 9844 with 1 tries
# Succeded at 9845 with 3 tries
# Succeded at 9846 with 6 tries
# Succeded at 9847 with 3 tries
# Succeded at 9848 with 3 tries
# Succeded at 9849 with 3 tries
# Succeded at 9850 with 4 tries
# Succeded at 9852 with 2 tries
# Succeded at 9854 with 1 tries
# Succeded at 9855 with 5 tries
# Succeded at 9856 with 3 tries
# Succeded at 9857 with 3 tries
# Succeded at 9858 with 3 tries
# Succeded at 9859 with 1 tries
# Succeded at 9860 with 1 tries
# Succeded at 9861 with 1 tries
# Succeded at 9862 with 3 tries
# Succeded at 9863 with 1 tries
# Succeded at 9864 with 6 tries
# Succeded at 9865 with 7 tries
# Succeded at 9866 with 3 tries
# Succeded at 9867 with 2 tries
# Succeded at 9869 with 5 tries
# Succeded at 9870 with 7 tries
# Succeded at 9871 with 3 tries
# Succeded at 9872 with 3 tries
# Succeded at 9873 with 3 tries
# Succeded at 9874 with 9 tries
# Succeded at 9876 with 8 tries
# Succeded at 9877 with 8 tries
# Succeded at 9878 with 1 tries
# Succeded at 9879 with 3 tries
# Succeded at 9880 with 8 tries
# Succeded at 9881 with 1 tries
# Succeded at 9882 with 6 tries
# Succeded at 9883 with 1 tries
# Succeded at 9884 with 3 tries
# Succeded at 9885 with 4 tries
# Succeded at 9886 with 1 tries
# Succeded at 9887 with 5 tries
# Succeded at 9888 with 2 tries
# Succeded at 9889 with 2 tries
# Succeded at 9890 with 1 tries
# Succeded at 9891 with 3 tries
# Succeded at 9893 with 6 tries
# Succeded at 9894 with 3 tries
# Succeded at 9895 with 4 tries
# Succeded at 9896 with 1 tries
# Succeded at 9898 with 6 tries
# Succeded at 9899 with 5 tries
# Succeded at 9900 with 1 tries
# Succeded at 9901 with 3 tries
# Succeded at 9902 with 5 tries
# Succeded at 9903 with 2 tries
# Succeded at 9904 with 2 tries
# Succeded at 9905 with 2 tries
# Succeded at 9906 with 1 tries
# Succeded at 9907 with 2 tries
# Succeded at 9908 with 3 tries
# Succeded at 9909 with 1 tries
# Succeded at 9910 with 2 tries
# Succeded at 9911 with 1 tries
# Succeded at 9912 with 4 tries
# Succeded at 9913 with 1 tries
# Succeded at 9914 with 3 tries
# Succeded at 9915 with 1 tries
# Succeded at 9916 with 8 tries
# Succeded at 9917 with 2 tries
# Succeded at 9918 with 2 tries
# Succeded at 9919 with 3 tries
# Succeded at 9920 with 3 tries
# Succeded at 9921 with 3 tries
# Succeded at 9923 with 1 tries
# Succeded at 9924 with 2 tries
# Succeded at 9925 with 8 tries
# Succeded at 9926 with 1 tries
# Succeded at 9927 with 3 tries
# Succeded at 9929 with 9 tries
# Succeded at 9930 with 4 tries
# Succeded at 9931 with 4 tries
# Succeded at 9932 with 6 tries
# Succeded at 9933 with 7 tries
# Succeded at 9934 with 1 tries
# Succeded at 9935 with 3 tries
# Succeded at 9936 with 10 tries
# Succeded at 9937 with 1 tries
# Succeded at 9938 with 1 tries
# Succeded at 9939 with 3 tries
# Succeded at 9941 with 6 tries
# Succeded at 9943 with 1 tries
# Succeded at 9944 with 5 tries
# Succeded at 9945 with 6 tries
# Succeded at 9946 with 6 tries
# Succeded at 9947 with 2 tries
# mosek failed at
# Succeded at 9948 with 10 tries
# Succeded at 9950 with 3 tries
# Succeded at 9951 with 1 tries
# Succeded at 9952 with 8 tries
# Succeded at 9953 with 2 tries
# Succeded at 9954 with 5 tries
# Succeded at 9955 with 1 tries
# Succeded at 9956 with 3 tries
# Succeded at 9957 with 5 tries
# Succeded at 9958 with 5 tries
# Succeded at 9960 with 3 tries
# Succeded at 9961 with 1 tries
# Succeded at 9962 with 3 tries
# Succeded at 9965 with 6 tries
# Succeded at 9966 with 3 tries
# Succeded at 9967 with 3 tries
# Succeded at 9970 with 3 tries
# Succeded at 9971 with 2 tries
# Succeded at 9972 with 1 tries
# Succeded at 9973 with 8 tries
# Succeded at 9974 with 2 tries
# Succeded at 9975 with 1 tries
# Succeded at 9976 with 1 tries
# Succeded at 9977 with 2 tries
# Succeded at 9978 with 1 tries
# Succeded at 9979 with 7 tries
# Succeded at 9981 with 1 tries
# Succeded at 9982 with 4 tries
# Succeded at 9986 with 8 tries
# Succeded at 9988 with 4 tries
# Succeded at 9990 with 6 tries
# Succeded at 9991 with 3 tries
# Succeded at 9992 with 7 tries
# Succeded at 9993 with 3 tries
# Succeded at 9994 with 3 tries
# Succeded at 9997 with 3 tries
# Succeded at 9999 with 1 tries

# %%
global_acc = sum(sum(np.equal(ind_max,pp.labels[test_start:,0][:,None])))/(0.1*pp.n_probs)
global_acc

# %%
np.mean(feasible[:ii])
# Out:
# 0.7764776477647765
